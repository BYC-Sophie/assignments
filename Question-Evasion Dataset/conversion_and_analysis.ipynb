# %% [markdown]
# import

# %%
# %pip install datasets convokit ipykernel
# Out:
# Requirement already satisfied: datasets in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (4.0.0)
# Requirement already satisfied: convokit in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (3.4.1)
# Requirement already satisfied: ipykernel in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (6.30.1)
# Requirement already satisfied: filelock in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (2.3.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (0.34.4)
# Requirement already satisfied: packaging in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (3.10.6)
# Requirement already satisfied: scipy>1.14 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (1.16.1)
# Requirement already satisfied: msgpack-numpy>=0.4.3.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (0.4.8)
# Requirement already satisfied: spacy>=3.8.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (3.8.7)
# Requirement already satisfied: scikit-learn>=1.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (1.7.1)
# Requirement already satisfied: nltk>=3.4 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (3.9.1)
# Requirement already satisfied: joblib>=0.13.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (1.5.2)
# Requirement already satisfied: clean-text>=0.6.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (0.6.0)
# Requirement already satisfied: unidecode>=1.1.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (1.4.0)
# Requirement already satisfied: pymongo>=4.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (4.14.1)
# Requirement already satisfied: dnspython>=1.16.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (2.7.0)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (8.3.6)
# Requirement already satisfied: h5py==3.12.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (3.12.1)
# Requirement already satisfied: numexpr>=2.8.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (2.11.0)
# Requirement already satisfied: ruff>=0.4.8 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (0.12.11)
# Requirement already satisfied: bottleneck in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from convokit) (1.5.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (27.0.2)
# Requirement already satisfied: tornado>=6.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: emoji<2.0.0,>=1.0.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from clean-text>=0.6.0->convokit) (1.7.0)
# Requirement already satisfied: ftfy<7.0,>=6.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from clean-text>=0.6.0->convokit) (6.3.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.9)
# Requirement already satisfied: decorator in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from matplotlib>=3.0.0->convokit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from matplotlib>=3.0.0->convokit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from matplotlib>=3.0.0->convokit) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from matplotlib>=3.0.0->convokit) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from matplotlib>=3.0.0->convokit) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from matplotlib>=3.0.0->convokit) (3.2.3)
# Requirement already satisfied: msgpack>=0.5.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from msgpack-numpy>=0.4.3.2->convokit) (1.1.1)
# Requirement already satisfied: click in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from nltk>=3.4->convokit) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from nltk>=3.4->convokit) (2025.8.29)
# Requirement already satisfied: pytz>=2020.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2025.8.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from scikit-learn>=1.0->convokit) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (3.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (0.17.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (2.11.7)
# Requirement already satisfied: jinja2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (3.1.6)
# Requirement already satisfied: setuptools in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (80.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from spacy>=3.8.2->convokit) (3.5.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (0.1.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: wcwidth in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from ftfy<7.0,>=6.0->clean-text>=0.6.0->convokit) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: language-data>=1.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3.8.2->convokit) (1.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.8.2->convokit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.8.2->convokit) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.8.2->convokit) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (14.1.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.8.2->convokit) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.8.2->convokit) (7.3.0.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from jinja2->spacy>=3.8.2->convokit) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.8.2->convokit) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (4.0.0)
# Requirement already satisfied: wrapt in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3.8.2->convokit) (1.17.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (0.1.2)
#
# [notice] A new release of pip is available: 25.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os, re, json, shutil, datetime, zipfile
from pathlib import Path

DATA_CSV= "./QAEvasion.csv"
OUT_DIR="./QuestionEvasion-convokit"
ZIP_BASE = "./QuestionEvasion-convokit"

if os.path.exists(OUT_DIR):
    shutil.rmtree(OUT_DIR)
os.makedirs(OUT_DIR, exist_ok=True)

# %% [markdown]
# 1) read the CSV

# %%
df = pd.read_csv(
    DATA_CSV,
    engine="python",
    sep=",",
    quotechar='"'
)
print("rows:",len(df))
df.head(2)
# Out:
# rows: 3448
#                                                title                date  \
# 0  The President's News Conference in Hanoi, Vietnam  September 10, 2023
# 1  The President's News Conference in Hanoi, Vietnam  September 10, 2023
#
#          president                                                url  \
# 0  Joseph R. Biden  https://www.presidency.ucsb.edu/documents/the-...
# 1  Joseph R. Biden  https://www.presidency.ucsb.edu/documents/the-...
#
#    question_order                                 interview_question  \
# 0               1  Q. Of the Biden administration. And accused th...
# 1               1  Q. Of the Biden administration. And accused th...
#
#                                     interview_answer  \
# 0  Well, look, first of all, theI am sincere abou...
# 1  Well, look, first of all, theI am sincere abou...
#
#                                       gpt3.5_summary  \
# 0  The question consists of 2 parts: \n1. How wou...
# 1  The question consists of 2 parts: \n1. How wou...
#
#                                    gpt3.5_prediction  \
# 0  Question part: 1. How would you respond to the...
# 1  Question part: 1. How would you respond to the...
#
#                                             question     label  annotator_id  \
# 0  How would you respond to the accusation that t...  Explicit            85
# 1  Do you think President Xi is being sincere abo...   General            85
#
#    inaudible  multiple_questions  affirmative_questions  index
# 0      False               False                  False      0
# 1      False               False                  False      1

# %% [markdown]
# 2) clean up

# %%
def norm_id(x):
    s= "" if pd.isna(x) else str(x)
    s=s.strip()
    s =re.sub(r"\s+", "_", s)
    s=re.sub(r"[^A-Za-z0-9_]+", "", s)
    return s or "NA"

def to_boolish(v):
    s = str(v).strip().lower()
    return s in {"true","t","1","y","yes"}

# these three come in as TRUE/FALSE
for c in ["inaudible","multiple_questions","affirmative_questions"]:
    if c not in df.columns:
        df[c]= False
    else:
        df[c]=df[c].apply(to_boolish)

if "index" in df.columns:
    df["_row_id"]=df["index"].astype(str)
else:
    df["_row_id"] =df.index.astype(str)

# numeric-ish
if "question_order" in df.columns:
    df["question_order"] = pd.to_numeric(df["question_order"], errors="coerce").fillna(-1).astype(int)
else:
    df["question_order"] = -1

# %% [markdown]
# 3) build speakers (dict per spec: name to meta)

# %%
speakers = {}

interviewer_id = "interviewer_generic"
speakers[interviewer_id] ={"role": "interviewer", "name":"Interviewer"}

for name in sorted(df["president"].dropna().unique()):
    sid = f"PRES_{norm_id(name)}"
    speakers[sid] = {"role":"interviewee", "name": str(name)}

print("speakers:",len(speakers))
# Out:
# speakers: 5

# %% [markdown]
# 4) make conversations + utterances

# %%
conversations = {}
utterance_rows = []

for _, row in df.iterrows():
    pres_name = str(row.get("president", "Unknown"))
    pres_id=f"PRES_{norm_id(pres_name)}"
    if pres_id not in speakers:
        speakers[pres_id] = {"role": "interviewee", "name": pres_name}

    #ids for this QA pair
    q_uid=f"Q_{row['_row_id']}"      #question utterance id 
    a_uid = f"A_{row['_row_id']}"      # answer utterance id
    conv_id = q_uid                   # conversation_id == id of first utterance

    # normalize question_order
    q_order=int(row.get("question_order", -1))

    # (1) conversation meta
    conversations[conv_id] = {
        "title": row.get("title", ""),
        "date": row.get("date", ""),
        "url": row.get("url", ""),
        "president": pres_name,

        "question_order": q_order
    }

    # (2) question text
    q_text=row.get("question", "")
    if pd.isna(q_text) or not str(q_text).strip():
        q_text = row.get("interview_question", "")

    # question utterance meta
    q_meta = {
        "type": "question",
        "question_order":q_order,
        "interview_question_raw": row.get("interview_question", ""),
        "gpt35_summary": row.get("gpt3.5_summary", ""),
        "title": row.get("title", ""),
        "date":row.get("date", ""),
        "url": row.get("url", "")
    }

    utterance_rows.append({
        "id":q_uid,
        "speaker": interviewer_id,
        "conversation_id": conv_id,
        "reply_to": None,
        "timestamp": None,
        "text":str(q_text),
        "meta":q_meta
    })

    # (3) answer side
    label_val = str(row.get("label", ""))
    a_meta = {
        "type":"answer",
        "question_order":q_order,
        "label": label_val,
        "annotator_id": str(row.get("annotator_id", "")),
        "inaudible":bool(row.get("inaudible", False)),
        "multiple_questions": bool(row.get("multiple_questions", False)),
        "affirmative_questions":bool(row.get("affirmative_questions", False)),
        "interview_answer_raw":row.get("interview_answer", ""),
        "gpt35_prediction":row.get("gpt3.5_prediction", "")
    }

    utterance_rows.append({
        "id": a_uid,
        "speaker": pres_id,
        "conversation_id": conv_id,
        "reply_to":q_uid,
        "timestamp":None,
        "text":str(row.get("interview_answer", "")),
        "meta": a_meta
    })

print("made utterances:",len(utterance_rows), "conversations:", len(conversations))
# Out:
# made utterances: 6896 conversations: 3448

# %% [markdown]
# 5) write files

# %%
# utterances.jsonl
utt_path = os.path.join(OUT_DIR, "utterances.jsonl")
with open(utt_path, "w", encoding="utf-8") as f:
    for r in utterance_rows:
        f.write(json.dumps(r, ensure_ascii=False) + "\n")

#speakers.json
spk_path = os.path.join(OUT_DIR, "speakers.json")
with open(spk_path,"w",encoding="utf-8") as f:
    f.write(json.dumps(speakers, indent=2, ensure_ascii=False))

# conversations.json
conv_path = os.path.join(OUT_DIR,"conversations.json")
with open(conv_path, "w", encoding="utf-8") as f:
    f.write(json.dumps(conversations, indent=2, ensure_ascii=False))

# corpus.json 
corpus_meta = {
    "name": "Question Evasion (ConvoKit)",
    "source": "QAEvasion.csv",
    "created": datetime.datetime.utcnow().isoformat() + "Z"
}

corp_path=os.path.join(OUT_DIR, "corpus.json")

with open(corp_path, "w", encoding="utf-8") as f:
    f.write(json.dumps(corpus_meta, indent=2, ensure_ascii=False))

#index.json
def infer_type_str(val):
    if isinstance(val, bool): return "<class 'bool'>"
    if isinstance(val, int):  return "<class 'int'>"
    
    if isinstance(val, float):return "<class 'float'>"
    return "<class 'str'>"

# union of all utterance meta key
utt_meta_keys=set()
for r in utterance_rows:
    for k in (r.get("meta") or {}):
        utt_meta_keys.add(k)

# speaker meta keys
spk_meta_keys =set()
for k, meta in speakers.items():
    for mk in (meta or {}):
        spk_meta_keys.add(mk)

# conversation meta keys
conv_meta_keys = set()
for k, meta in conversations.items():
    for mk in (meta or {}):
        conv_meta_keys.add(mk)

index_obj = {
    "utterances-index":{ k: "<class 'str'>" for k in sorted(utt_meta_keys) },
    "speakers-index":{ k: "<class 'str'>" for k in sorted(spk_meta_keys) },
    "conversations-index": {k: "<class 'str'>" for k in sorted(conv_meta_keys) },
    "overall-index": {kk: infer_type_str(v) for kk, v in corpus_meta.items() },
    "version": 1
}
idx_path = os.path.join(OUT_DIR, "index.json")
with open(idx_path, "w", encoding="utf-8") as f:
    f.write(json.dumps(index_obj, indent=2, ensure_ascii=False))

for p in [utt_path, spk_path, conv_path, corp_path, idx_path]:
    print(Path(p).name, "bytes=", Path(p).stat().st_size)
# Out:
# utterances.jsonl bytes= 22483052
# speakers.json bytes= 436
# conversations.json bytes= 989337
# corpus.json bytes= 116
# index.json bytes= 954

# %% [markdown]
# 6) print stats

# %%
n_convos = len(conversations)
n_utts   = len(utterance_rows)
n_speaks = len(speakers)

label_counts = df["label"].astype(str).str.strip().value_counts().sort_index()
inaudible_true = int(df["inaudible"].sum())
multi_true= int(df["multiple_questions"].sum())
affirm_true    = int(df["affirmative_questions"].sum())

print("==== Basic Stats (Question Evasion, ConvoKit) ====")
print("Conversations:", n_convos)
print("Utterances:", n_utts)
print("Speakers:", n_speaks)
print("\nLabel distribution:")
print(label_counts.to_string())
print("\nFlags:")
print("inaudible =", inaudible_true)
print("multiple_questions =", multi_true)
print("affirmative_questions =", affirm_true)
print("===============================================")
# Out:
# ==== Basic Stats (Question Evasion, ConvoKit) ====
# Conversations: 3448
# Utterances: 6896
# Speakers: 5
#
# Label distribution:
# label
# Claims ignorance        119
# Clarification            92
# Declining to answer     145
# Deflection              381
# Dodging                 706
# Explicit               1052
# General                 386
# Implicit                488
# Partial/half-answer      79
#
# Flags:
# inaudible = 45
# multiple_questions = 86
# affirmative_questions = 772
# ===============================================

# %% [markdown]
# 7) zip it

# %%
zip_path = shutil.make_archive(ZIP_BASE, "zip", OUT_DIR)
print("zipped here:", zip_path)
with zipfile.ZipFile(zip_path, 'r') as zf:
    print("zip members:")
    for m in zf.namelist():
        print("  -", m)
# Out:
# zipped here: /Users/bolinsong/Desktop/NLP and Social Interaction/Question-Evasion Dataset/QuestionEvasion-convokit.zip
# zip members:
#   - utterances.jsonl
#   - conversations.json
#   - corpus.json
#   - speakers.json
#   - index.json

# %%
from convokit import Corpus, Speaker, Utterance, Conversation

# %%
corpus = Corpus(filename="./QuestionEvasion-convokit")
print(len(list(corpus.iter_conversations())))
# Out:
# 3448

# %%
corpus.print_summary_stats()
# Out:
# Number of Speakers: 5
# Number of Utterances: 6896
# Number of Conversations: 3448

# %%
convo = corpus.random_conversation()
print(convo)
# Out:
# Conversation('id': 'Q_2622', 'utterances': ['Q_2622', 'A_2622'], 'meta': {'title': "The President's News Conference With President Felipe de Jesus Calderon Hinojosa of Mexico and Prime Minister Stephen Harper of Canada in Guadalajara, Mexico", 'date': 'August 10, 2009', 'url': 'https://www.presidency.ucsb.edu/documents/the-presidents-news-conference-with-president-felipe-de-jesus-calderon-hinojosa-mexico-and', 'president': 'Barack Obama', 'question_order': 1})

# %%
convo.print_conversation_structure()
# Out:
# interviewer_generic
#     PRES_Barack_Obama

# %%
speaker = corpus.random_speaker()
print(speaker)
# Out:
# Speaker(id: PRES_Barack_Obama, vectors: [], meta: {'role': 'interviewee', 'name': 'Barack Obama'})

# %%
for utt in corpus.iter_utterances():
    print(utt.text)
    break
# Out:
# How would you respond to the accusation that the United States is containing China while pushing for diplomatic talks?

# %% [markdown]
# ### Annotating the Corpus with bag-of-words vectors

# %%
from convokit import BoWTransformer

# %%
bow_transformer = BoWTransformer(obj_type="utterance", vector_name="bow_A")
# Out:
# Initializing default unigram CountVectorizer...Done.

# %%
# before transformation
corpus.get_utterance('Q_1503').vectors
# Out:
# []

# %%
bow_transformer.fit_transform(corpus)

# %%
# after transformation
corpus.get_utterance('Q_1503').vectors
# Out:
# ['bow_A']

# %%
corpus.vectors
# Out:
# {'bow_A'}

# %%
corpus.get_vector_matrix('bow_A')
# Out:
# ConvoKitMatrix('name': bow_A, 'matrix': <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 452700 stored elements and shape (6896, 4679)>)

# %%
corpus.random_utterance().meta
# Out:
# {'type': 'answer',
#  'question_order': 3,
#  'label': 'Explicit',
#  'annotator_id': '89',
#  'inaudible': False,
#  'multiple_questions': False,
#  'affirmative_questions': True,
#  'interview_answer_raw': "We are looking very seriously at going back to Poland. And I don't know what the President has in store for us, but we're thinking about going back sometime in September. Yes. Thank you.",
#  'gpt35_prediction': 'Question part: 1 - Confirmation of meeting in September in Warsaw\nVerdict: 1.2 Implicit - The information is given without being explicitly stated in the requested form.\nExplanation: The response states that they are thinking about going back to Poland in September, which implies the possibility of meeting in Warsaw. However, it does not explicitly confirm the meeting in Warsaw in September.'}

# %%
corpus.random_utterance().meta
# Out:
# {'type': 'question',
#  'question_order': 6,
#  'interview_question_raw': "Q. ——got the Cleveland connection, so I appreciate that. You cited the Mayo Clinic and the Cleveland Clinics as models for the delivery of health care in the past. The Mayo Clinic, though, has some problems with the House proposal, saying they're not focused enough on patients and on results. What do you expect to achieve tomorrow by going to the Cleveland Clinic, which hasn't stated an opinion, and are you expecting some form of endorsement from the Cleveland Clinic?",
#  'gpt35_summary': "The question consists of 2 parts:\n\n1. Mayo Clinic's problems with the House proposal:\n- What problems does the Mayo Clinic have with the House proposal?\n- Why do they believe the proposal is not focused enough on patients and on results?\n\n2. Expectations from visiting the Cleveland Clinic:\n- What does the speaker expect to achieve by going to the Cleveland Clinic?\n- Is the speaker expecting some form of endorsement from the Cleveland Clinic?\n\n<--Summary Answer-->\n\nThe response provides the following information regarding these points:\n\n1. Mayo Clinic's problems with the House proposal:\n- The Mayo Clinic initially had concerns and was critical of the original House bill.\n- They were specifically concerned about the delivery system and cost-saving measures.\n- However, after learning about the specific mechanisms like the MedPAC idea (experts making decisions based on evidence), they expressed support for these ideas.\n\n2. Expectations from visiting the Cleveland Clinic:\n- The speaker is not expecting an endorsement from the Cleveland Clinic.\n- The Cleveland Clinic is seen as a role model for the desired changes in healthcare delivery.\n\nThere is no information provided regarding the question about tomorrow's visit to the Cleveland Clinic and what the speaker hopes to achieve.",
#  'title': "The President's News Conference",
#  'date': 'July 22, 2009',
#  'url': 'https://www.presidency.ucsb.edu/documents/the-presidents-news-conference-1121'}

# %%
corpus.random_utterance()
# Out:
# Utterance({'obj_type': 'utterance', 'meta': {'type': 'question', 'question_order': 2, 'interview_question_raw': "Q. Tajiri, Kyodo News. At Camp David with history. I do have a question to each of the leaders.Mr. President Biden—President Biden, it was mentioned at this summit meeting that Russia's aggression of Ukraine is continuing. So what role do you expect of Japan?Prime Minister Kishida has mentioned that as China's threat in Asia is rising, Ukraine may be East Asia tomorrow. What do you think about this comment, President Biden?And the situation in Asia, where China's threat is rising, what is the meaning and significance of the trilateral relationship with Japan, U.S., R.O.K. becoming stronger in multiple layers?", 'gpt35_summary': "The question consists of 6 parts: \n1. Russia's aggression in Ukraine and Japan's role\n2. China's threat in Asia and the comment made by Prime Minister Kishida \n3. The significance of the trilateral relationship between Japan, U.S., and R.O.K. \n4. North Korea's nuclear missile development and the significance of the partnership between Japan, South Korea, and the U.S. \n5. The release of treated water at Fukushima Daiichi nuclear power plant and Prime Minister Kishida's explanation \n6. Prime Minister Kishida's intent to respect the IAEA report and the reason for supporting the policy of the Kishida administration \n\nThe response provides the following information regarding these points:\n1. Regarding Russia's aggression in Ukraine and Japan's role, President Biden acknowledges Japan's strong leadership and the significant financial and humanitarian assistance provided by Japan to Ukraine. He also mentions Japan's contribution to holding Russia accountable through international sanctions. \n2. President Biden does not directly address the comment made by Prime Minister Kishida regarding China's threat in Asia and Ukraine potentially becoming East Asia tomorrow. \n3. President Biden states that the trilateral relationship between Japan, U.S., and R.O.K. becoming stronger in multiple layers is significant for a more peaceful and prosperous Indo-Pacific, and it goes beyond the immediate issues raised in the summit. He emphasizes the impact of the relationship in the region and around the world. \n4. President Biden addresses the significance of the partnership between Japan, South Korea, and the U.S. in the face of North Korea's nuclear missile development. He mentions the escalating provocations of North Korea and the need for the three countries to declare a new era of partnership for security. \n5. There is no information provided in the response regarding the release of treated water at the Fukushima Daiichi nuclear power plant and Prime Minister Kishida's explanation. \n6. President Biden does not directly answer the question regarding Prime Minister Kishida's intent to respect the IAEA report and his support for the policy of the Kishida administration.", 'title': "The President's News Conference With President Yoon Suk Yeol of South Korea and Prime Minister Fumio Kishida of Japan at Camp David, Maryland", 'date': 'August 18, 2023', 'url': 'https://www.presidency.ucsb.edu/documents/the-presidents-news-conference-with-president-yoon-suk-yeol-south-korea-and-prime-minister'}, 'vectors': ['bow_A'], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'role': 'interviewer', 'name': 'Interviewer'}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x149c08320>, 'id': 'interviewer_generic'}), 'conversation_id': 'Q_346', 'reply_to': None, 'timestamp': None, 'text': "The release of treated water at Fukushima Daiichi nuclear power plant and Prime Minister Kishida's explanation", 'owner': <convokit.model.corpus.Corpus object at 0x149c08320>, 'id': 'Q_346'})

# %%
corpus.random_conversation().meta
# Out:
# {'title': "The President's News Conference in Osaka, Japan",
#  'date': 'June 29, 2019',
#  'url': 'https://www.presidency.ucsb.edu/documents/the-presidents-news-conference-osaka-japan',
#  'president': 'Donald J. Trump',
#  'question_order': 22}

# %%
corpus.random_conversation()
# Out:
# Conversation({'obj_type': 'conversation', 'meta': {'title': "The President's News Conference", 'date': 'August 04, 2020', 'url': 'https://www.presidency.ucsb.edu/documents/the-presidents-news-conference-1249', 'president': 'Donald J. Trump', 'question_order': 1}, 'vectors': [], 'tree': None, 'owner': <convokit.model.corpus.Corpus object at 0x149c08320>, 'id': 'Q_693'})

# %%
from collections import Counter
type_counts = Counter([u.meta.get("type") for u in corpus.iter_utterances()])
print(type_counts)
# Out:
# Counter({'question': 3448, 'answer': 3448})

# %%
q_labels = [u.meta.get("label") for u in corpus.iter_utterances() if u.meta.get("type")=="question"]
print("Question labels:", set(q_labels))
# Out:
# Question labels: {None}

# %%
a_labels = [u.meta.get("label") for u in corpus.iter_utterances() if u.meta.get("type")=="answer"]
print("Answer labels:", Counter(a_labels))
# Out:
# Answer labels: Counter({'Explicit': 1052, 'Dodging': 706, 'Implicit': 488, 'General': 386, 'Deflection': 381, 'Declining to answer': 145, 'Claims ignorance': 119, 'Clarification': 92, 'Partial/half-answer': 79})

# %%
import re

def norm(s):
    return re.sub(r"\s+", " ", s.strip().lower())

CLEAR_REPLY = {"Explicit"}
AMBIV_REPLY = {"Implicit", "Dodging", "General", "Deflection", "Partial/half-answer"}
CLEAR_NON   = {"Declining to answer", "Claims ignorance", "Clarification"}

def map_label(lbl):
    if lbl in CLEAR_REPLY:
        return "clear-reply"
    elif lbl in AMBIV_REPLY:
        return "ambivalent-reply"
    elif lbl in CLEAR_NON:
        return "clear-nonreply"
    else:
        return None

for u in corpus.iter_utterances():
    if u.meta.get("type") == "answer" and "label" in u.meta:
        u.meta["coarse_label"] = map_label(u.meta["label"])

coarse_counts = Counter(
    u.meta.get("coarse_label")
    for u in corpus.iter_utterances()
    if u.meta.get("type") == "answer"
)
print(coarse_counts)
# Out:
# Counter({'ambivalent-reply': 2040, 'clear-reply': 1052, 'clear-nonreply': 356})

# %% [markdown]
# ### Classfier: Answer Only

# %%
from convokit import VectorClassifier

# %%
convo = corpus.random_conversation()
print(convo)
# Out:
# Conversation('id': 'Q_1517', 'utterances': ['Q_1517', 'A_1517'], 'meta': {'title': "The President's News Conference on Sentosa Island, Singapore", 'date': 'June 12, 2018', 'url': 'https://www.presidency.ucsb.edu/documents/the-presidents-news-conference-sentosa-island-singapore', 'president': 'Donald J. Trump', 'question_order': 10})

# %%
from collections import Counter

def labeller(u):
    return u.meta.get("coarse_label") if u.meta.get("type")=="answer" else None

# 1) 看看 labeller 返回了什么
vals = [labeller(u) for u in corpus.iter_utterances()]
print("含 None 的统计：", Counter(x if x is not None else "__NONE__" for x in vals))

# 2) 只保留可用样本（answer 且有 coarse_label）
usable = [u for u in corpus.iter_utterances()
          if u.meta.get("type")=="answer" and isinstance(u.meta.get("coarse_label"), (str, int))]
print("可用样本数：", len(usable))
print("类别分布：", Counter(u.meta["coarse_label"] for u in usable) )

# 3) 检查是否存在奇怪类型
bad = [u.meta.get("coarse_label") for u in corpus.iter_utterances()
       if u.meta.get("type")=="answer" and not isinstance(u.meta.get("coarse_label"), (str, int))]
print("异常类型样例（前5个）：", bad[:5])
# Out:
# 含 None 的统计： Counter({'__NONE__': 3448, 'ambivalent-reply': 2040, 'clear-reply': 1052, 'clear-nonreply': 356})
# 可用样本数： 3448
# 类别分布： Counter({'ambivalent-reply': 2040, 'clear-reply': 1052, 'clear-nonreply': 356})
# 异常类型样例（前5个）： []

# %%
is_ans_labeled = lambda u: u.meta.get("type")=="answer" and "coarse_label" in u.meta

# %%
clf = VectorClassifier(
    obj_type="utterance",
    vector_name="bow_A",
    labeller=lambda u: u.meta.get("coarse_label") if is_ans_labeled(u) else None
)
# Out:
# Initialized default classification model (standard scaled logistic regression).

# %%
clf.fit_transform(corpus, selector=is_ans_labeled)   # ← 这里一定要过滤
# Out:
# /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(
# /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
df = clf.summarize(corpus)

# %%
print(len(df))        # 总行数
print(df.shape)       # (行数, 列数)
# Out:
# 6896
# (6896, 2)

# %%
df
# Out:
#             prediction  pred_score
# id
# A_3229  clear-nonreply    1.000000
# A_2722  clear-nonreply    0.999686
# A_2723  clear-nonreply    0.999686
# A_2676  clear-nonreply    0.999330
# A_1966  clear-nonreply    0.999114
# ...                ...         ...
# Q_3443            None         NaN
# Q_3444            None         NaN
# Q_3445            None         NaN
# Q_3446            None         NaN
# Q_3447            None         NaN
#
# [6896 rows x 2 columns]

# %%
print(df['prediction'].value_counts(dropna=False))
# Out:
# prediction
# None                3448
# ambivalent-reply    2134
# clear-reply          994
# clear-nonreply       320
# Name: count, dtype: int64

# %%
clf     # (n_classes, n_features)

# %%
from collections import Counter
y_true, _ = clf.get_y_true_pred(corpus, selector=is_ans_labeled)  # 只取有label的
cnt = Counter(y_true)
maj_label, maj_count = max(cnt.items(), key=lambda x: x[1])
base_acc = maj_count / sum(cnt.values())
print("Majority label:", maj_label)
print("Base accuracy:", base_acc)
# Out:
# Majority label: ambivalent-reply
# Base accuracy: 0.5916473317865429

# %%
clf.accuracy(corpus, selector=is_ans_labeled)
# Out:
# np.float64(0.8474477958236659)

# %%
print(clf.classification_report(corpus, selector=is_ans_labeled))
# Out:
#                   precision    recall  f1-score   support
#
# ambivalent-reply       0.86      0.90      0.88      2040
#   clear-nonreply       0.88      0.79      0.83       356
#      clear-reply       0.81      0.76      0.78      1052
#
#         accuracy                           0.85      3448
#        macro avg       0.85      0.82      0.83      3448
#     weighted avg       0.85      0.85      0.85      3448

# %% [markdown]
# ### Questions as Context

# %%
# 预构建映射
aq_text = {}
for conv in corpus.iter_conversations():
    for uid in conv.get_utterance_ids(): 
        if uid.startswith("A_"):
            qid = "Q_" + uid.split("_", 1)[1]
            q = corpus.get_utterance(qid)
            aq_text[uid] = (q.text if q and q.text else "")

# %%
aq_text[:5]

# %%
corpus.get_utterance('Q_1000').text
# Out:
# 'Expectations for further actions regarding FETÖ'

# %%
list(aq_text.items())[1000]
# Out:
# ('A_1000', 'Expectations for further actions regarding FETÖ')

# %%
re_tok = re.compile(r"\w+")

def qa_prefixed(u):
    if u.meta.get("type") != "answer":  
        return None   # 只给 answer 生成向量
    
    # 找到对应的 question 文本
    q_text = aq_text.get(u.id, "") or ""
    a_text = u.text or ""

    # 给每个 token 加上来源前缀
    q_tokens = [f"Q_{m.group(0).lower()}" for m in re_tok.finditer(q_text)]
    a_tokens = [f"A_{m.group(0).lower()}" for m in re_tok.finditer(a_text)]

    # 拼成一个字符串返回
    return " ".join(q_tokens + a_tokens)

bow_QA = BoWTransformer(
    obj_type="utterance",
    vector_name="bow_QA_prefixed",
    text_func=qa_prefixed
)
# Out:
# Initializing default unigram CountVectorizer...Done.

# %%
bow_QA.fit_transform(corpus, selector=is_ans_labeled)

# %%
corpus.vectors
# Out:
# {'bow_A', 'bow_QA_prefixed'}

# %%
answers = [u for u in corpus.iter_utterances() if u.meta.get("type")=="answer"]
labeled = [u for u in answers if "coarse_label" in u.meta]

print(f"Answers: {len(answers)}, labeled: {len(labeled)}")
# Out:
# Answers: 3448, labeled: 3448

# %%
u = corpus.get_utterance("A_2622")   # 换成你感兴趣的某个 answer ID
vec = u.get_vector("bow_QA_prefixed")
print(vec)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 17 stored elements and shape (1, 5091)>
#   Coords	Values
#   (0, 188)	1
#   (0, 758)	1
#   (0, 1145)	1
#   (0, 1740)	1
#   (0, 1754)	1
#   (0, 1761)	1
#   (0, 1880)	1
#   (0, 2362)	1
#   (0, 2766)	1
#   (0, 3196)	1
#   (0, 3721)	1
#   (0, 4259)	1
#   (0, 4505)	1
#   (0, 4687)	1
#   (0, 4790)	1
#   (0, 5016)	1
#   (0, 5088)	1

# %%
# 取出 BoW 的词表
vocab = bow_QA.vectorizer.get_feature_names_out()

# 随机挑一个 answer 看看
import random
u = random.choice([utt for utt in corpus.iter_utterances() if utt.meta.get("type")=="answer"])
vec = u.get_vector("bow_QA_prefixed")

print("Utterance ID:", u.id)
print("Original text:", u.text)
print("QA text_func:", qa_prefixed(u))   # 你定义的拼接
print("\nVector tokens:")

# 打印非零特征（token 和它的 count）
for idx, val in zip(vec.indices, vec.data):
    print(f"  {vocab[idx]}: {val}")
# Out:
# Utterance ID: A_928
# Original text: No, I think you have to always—look, I do it a lot anyway, as you've probably heard. Wash your hands, stay clean. [] You don't have to necessarily grab every handrail unless you have to. You know, you do certain things that you do when you have the flu.I mean, view this the same as the flu. When somebody sneezes—I mean, I try and bail out as much as possible when they're sneezing. [] I had a man come up to me a week ago. I hadn't seen him in a long time, and I said, How you doing? He said, Fine, fine. And he hugs me, kiss. I said, Are you well? He says, No. [] He said, I have the worst fever and the worst flu. And he's hugging and kissing me. So I said, Excuse me. I went, and I started washing my hands. [] So you have to do that.You know, this is—I really think, Doctor, you ought to treat this like you treat the flu, right? And, you know, it's going to be—it's going to be fine.
# QA text_func: Q_are Q_you Q_telling Q_the Q_americans Q_except Q_for Q_the Q_ones Q_who Q_are Q_sick Q_not Q_to Q_change Q_any Q_of Q_their Q_behaviors A_no A_i A_think A_you A_have A_to A_always A_look A_i A_do A_it A_a A_lot A_anyway A_as A_you A_ve A_probably A_heard A_wash A_your A_hands A_stay A_clean A_you A_don A_t A_have A_to A_necessarily A_grab A_every A_handrail A_unless A_you A_have A_to A_you A_know A_you A_do A_certain A_things A_that A_you A_do A_when A_you A_have A_the A_flu A_i A_mean A_view A_this A_the A_same A_as A_the A_flu A_when A_somebody A_sneezes A_i A_mean A_i A_try A_and A_bail A_out A_as A_much A_as A_possible A_when A_they A_re A_sneezing A_i A_had A_a A_man A_come A_up A_to A_me A_a A_week A_ago A_i A_hadn A_t A_seen A_him A_in A_a A_long A_time A_and A_i A_said A_how A_you A_doing A_he A_said A_fine A_fine A_and A_he A_hugs A_me A_kiss A_i A_said A_are A_you A_well A_he A_says A_no A_he A_said A_i A_have A_the A_worst A_fever A_and A_the A_worst A_flu A_and A_he A_s A_hugging A_and A_kissing A_me A_so A_i A_said A_excuse A_me A_i A_went A_and A_i A_started A_washing A_my A_hands A_so A_you A_have A_to A_do A_that A_you A_know A_this A_is A_i A_really A_think A_doctor A_you A_ought A_to A_treat A_this A_like A_you A_treat A_the A_flu A_right A_and A_you A_know A_it A_s A_going A_to A_be A_it A_s A_going A_to A_be A_fine
#
# Vector tokens:
#   a_ago: 1
#   a_always: 1
#   a_anyway: 1
#   a_bail: 1
#   a_certain: 1
#   a_clean: 1
#   a_come: 1
#   a_doctor: 1
#   a_doing: 1
#   a_don: 1
#   a_every: 1
#   a_excuse: 1
#   a_fine: 3
#   a_had: 1
#   a_hadn: 1
#   a_hands: 2
#   a_he: 5
#   a_heard: 1
#   a_him: 1
#   a_how: 1
#   a_know: 3
#   a_like: 1
#   a_long: 1
#   a_look: 1
#   a_lot: 1
#   a_man: 1
#   a_me: 4
#   a_mean: 2
#   a_much: 1
#   a_my: 1
#   a_necessarily: 1
#   a_no: 2
#   a_ought: 1
#   a_out: 1
#   a_possible: 1
#   a_probably: 1
#   a_really: 1
#   a_right: 1
#   a_said: 5
#   a_same: 1
#   a_says: 1
#   a_seen: 1
#   a_somebody: 1
#   a_started: 1
#   a_stay: 1
#   a_things: 1
#   a_time: 1
#   a_treat: 2
#   a_try: 1
#   a_unless: 1
#   a_up: 1
#   a_view: 1
#   a_week: 1
#   a_well: 1
#   a_went: 1
#   a_when: 3
#   a_worst: 2
#   a_your: 1
#   q_americans: 1
#   q_any: 1
#   q_are: 2
#   q_change: 1
#   q_for: 1
#   q_not: 1
#   q_of: 1
#   q_their: 1
#   q_to: 1
#   q_who: 1
#   q_you: 1

# %%
clf_QA = VectorClassifier(
    obj_type="utterance",
    vector_name="bow_QA_prefixed",
    labeller=lambda u: u.meta.get("coarse_label") if is_ans_labeled(u) else None
)
clf_QA.fit_transform(corpus, selector=is_ans_labeled)   # ← 这里一定要过滤
# Out:
# Initialized default classification model (standard scaled logistic regression).
# /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(

# %%
df = clf_QA.summarize(corpus)
df
# Out:
#             prediction  pred_score
# id
# A_1967  clear-nonreply    1.000000
# A_1966  clear-nonreply    1.000000
# A_1964  clear-nonreply    1.000000
# A_2063  clear-nonreply    1.000000
# A_825   clear-nonreply    0.999999
# ...                ...         ...
# Q_3443            None         NaN
# Q_3444            None         NaN
# Q_3445            None         NaN
# Q_3446            None         NaN
# Q_3447            None         NaN
#
# [6896 rows x 2 columns]

# %%
print(len(df))        # 总行数
print(df.shape)
# Out:
# 6896
# (6896, 2)

# %%
print(df['prediction'].value_counts(dropna=False))
# Out:
# prediction
# None                3448
# ambivalent-reply    2048
# clear-reply         1050
# clear-nonreply       350
# Name: count, dtype: int64

# %%
clf_QA.accuracy(corpus, selector=is_ans_labeled)
# Out:
# np.float64(0.9904292343387471)

# %%
print(clf_QA.classification_report(corpus, selector=is_ans_labeled))
# Out:
#                   precision    recall  f1-score   support
#
# ambivalent-reply       0.99      0.99      0.99      2040
#   clear-nonreply       1.00      0.98      0.99       356
#      clear-reply       0.99      0.99      0.99      1052
#
#         accuracy                           0.99      3448
#        macro avg       0.99      0.99      0.99      3448
#     weighted avg       0.99      0.99      0.99      3448

# %% [markdown]
# ### Generalizability Test

# %%
from sklearn.model_selection import train_test_split

# %%
answers = [u for u in corpus.iter_utterances() 
           if u.meta.get("type")=="answer" and "coarse_label" in u.meta]
print(len(answers))
# Out:
# 3448

# %%
# 分层抽样
y = [u.meta["coarse_label"] for u in answers]
train_utts, test_utts = train_test_split(answers, test_size=0.2, random_state=42, stratify=y)

for u in train_utts:
    u.meta["split"] = "train"
for u in test_utts:
    u.meta["split"] = "test"

# %%
# selectors
is_answer  = lambda u: u.meta.get("type") == "answer"
is_train_u = lambda u: is_answer(u) and u.meta.get("split") == "train"
is_test_u  = lambda u: is_answer(u) and u.meta.get("split") == "test"

# %%
bow_QA_split = BoWTransformer(
    obj_type="utterance",
    vector_name="bow_QA_prefixed_split",   # 新名字！
    text_func=qa_prefixed                  # 你的 Q+A 前缀拼接函数
)

# learn vocabulary in train dataset
bow_QA_split.fit(corpus, selector=is_train_u)

# vectorize train and test dataset
bow_QA_split.transform(corpus, selector=is_answer)
# Out:
# Initializing default unigram CountVectorizer...Done.

# %%
clf_QA_split = VectorClassifier(
    obj_type="utterance",
    vector_name="bow_QA_prefixed_split",
    labeller=lambda u: u.meta.get("coarse_label") if is_answer(u) else None
)

clf_QA_split.fit(corpus, selector=is_train_u)

clf_QA_split.transform(corpus, selector=is_answer)
# Out:
# Initialized default classification model (standard scaled logistic regression).
# /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(

# %%
# Evaluation
print("Train accuracy:", clf_QA_split.accuracy(corpus, selector=is_train_u))
print(clf_QA_split.classification_report(corpus, selector=is_train_u))

print("Test accuracy:", clf_QA_split.accuracy(corpus, selector=is_test_u))
print(clf_QA_split.classification_report(corpus, selector=is_test_u))
# Out:
# Train accuracy: 0.994198694706309
#                   precision    recall  f1-score   support
#
# ambivalent-reply       0.99      1.00      1.00      1632
#   clear-nonreply       1.00      0.99      0.99       285
#      clear-reply       0.99      0.99      0.99       841
#
#         accuracy                           0.99      2758
#        macro avg       1.00      0.99      0.99      2758
#     weighted avg       0.99      0.99      0.99      2758
#
# Test accuracy: 0.5507246376811594
#                   precision    recall  f1-score   support
#
# ambivalent-reply       0.65      0.65      0.65       408
#   clear-nonreply       0.44      0.38      0.41        71
#      clear-reply       0.41      0.42      0.41       211
#
#         accuracy                           0.55       690
#        macro avg       0.50      0.48      0.49       690
#     weighted avg       0.55      0.55      0.55       690

# %% [markdown]
# ### GenAI

# %%
df_test_result = clf_QA_split.summarize(corpus, selector=is_test_u)

# %%
df_test_result
# Out:
#               prediction    pred_score
# id
# A_1533    clear-nonreply  9.999426e-01
# A_1729    clear-nonreply  9.999145e-01
# A_1731    clear-nonreply  9.999145e-01
# A_1965    clear-nonreply  9.998740e-01
# A_1616    clear-nonreply  9.996702e-01
# ...                  ...           ...
# A_1817  ambivalent-reply  4.333080e-24
# A_1865  ambivalent-reply  3.361673e-24
# A_2399  ambivalent-reply  1.899436e-24
# A_1796       clear-reply  7.919053e-25
# A_1985  ambivalent-reply  5.797713e-32
#
# [690 rows x 2 columns]
