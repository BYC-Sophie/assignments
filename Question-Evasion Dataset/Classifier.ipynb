# %%
import pandas as pd
import os, re, json, shutil, datetime, zipfile
from pathlib import Path
from convokit import Corpus, Speaker, Utterance, Conversation
from collections import Counter
import re
# Out:
# /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages/convokit/coordination/coordination.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ### Load Corpus

# %%
corpus = Corpus(filename="./QuestionEvasion-convokit")
print(len(list(corpus.iter_conversations())))
# Out:
# 3448

# %%
# stats
corpus.print_summary_stats()
# Out:
# Number of Speakers: 5
# Number of Utterances: 6896
# Number of Conversations: 3448

# %%
# conversation
convo = corpus.random_conversation()
print(convo)
# Out:
# Conversation('id': 'Q_3010', 'utterances': ['Q_3010', 'A_3010'], 'meta': {'title': "The President's News Conference With Prime Minister Ehud Olmert of Israel in Jerusalem", 'date': 'January 09, 2008', 'url': 'https://www.presidency.ucsb.edu/documents/the-presidents-news-conference-with-prime-minister-ehud-olmert-israel-jerusalem', 'president': 'George W. Bush', 'question_order': 3})

# %%
# utterance
for utt in corpus.iter_utterances():
    print(utt.text)
    break
# Out:
# How would you respond to the accusation that the United States is containing China while pushing for diplomatic talks?

# %% [markdown]
# ## Hypothesis: Whether adding the question to the answer as context improves the accuracy of the classifier about whether the answer is ambiguous or not (i.e. ambivalent, clear, or clear-nonreply).

# %% [markdown]
# ### Pre-process Labels According to the Original Paper

# %%
# Labels are only included in the answer utterances
a_labels = [u.meta.get("label") for u in corpus.iter_utterances() if u.meta.get("type")=="answer"]
print("Answer labels:", Counter(a_labels))
# Out:
# Answer labels: Counter({'Explicit': 1052, 'Dodging': 706, 'Implicit': 488, 'General': 386, 'Deflection': 381, 'Declining to answer': 145, 'Claims ignorance': 119, 'Clarification': 92, 'Partial/half-answer': 79})

# %%
def norm(s):
    return re.sub(r"\s+", " ", s.strip().lower())

CLEAR_REPLY = {"Explicit"}
AMBIV_REPLY = {"Implicit", "Dodging", "General", "Deflection", "Partial/half-answer"}
CLEAR_NON   = {"Declining to answer", "Claims ignorance", "Clarification"}

def map_label(lbl):
    if lbl in CLEAR_REPLY:
        return "clear-reply"
    elif lbl in AMBIV_REPLY:
        return "ambivalent-reply"
    elif lbl in CLEAR_NON:
        return "clear-nonreply"
    else:
        return None

for u in corpus.iter_utterances():
    if u.meta.get("type") == "answer" and "label" in u.meta:
        u.meta["coarse_label"] = map_label(u.meta["label"])

coarse_counts = Counter(
    u.meta.get("coarse_label")
    for u in corpus.iter_utterances()
    if u.meta.get("type") == "answer"
)
print(coarse_counts)
# Out:
# Counter({'ambivalent-reply': 2040, 'clear-reply': 1052, 'clear-nonreply': 356})

# %% [markdown]
# ### Condition 1: Answer alone

# %%
#  bag-of-words vectors
from convokit import BoWTransformer
bow_transformer = BoWTransformer(obj_type="utterance", vector_name="bow_A")
bow_transformer.fit_transform(corpus)
# Out:
# Initializing default unigram CountVectorizer...Done.

# %%
# classifier
from convokit import VectorClassifier
# selector: as only answer utterances have labels
is_ans_labeled = lambda u: u.meta.get("type")=="answer" and "coarse_label" in u.meta

clf_A = VectorClassifier(
    obj_type="utterance",
    vector_name="bow_A",
    labeller=lambda u: u.meta.get("coarse_label") if is_ans_labeled(u) else None
)

clf_A.fit_transform(corpus, selector=is_ans_labeled)
# Out:
# Initialized default classification model (standard scaled logistic regression).
# /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(
# /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
# Evaluation
clf_A.summarize(corpus)
# Out:
#             prediction  pred_score
# id
# A_3229  clear-nonreply    1.000000
# A_2722  clear-nonreply    0.999686
# A_2723  clear-nonreply    0.999686
# A_2676  clear-nonreply    0.999330
# A_1966  clear-nonreply    0.999114
# ...                ...         ...
# Q_3443            None         NaN
# Q_3444            None         NaN
# Q_3445            None         NaN
# Q_3446            None         NaN
# Q_3447            None         NaN
#
# [6896 rows x 2 columns]

# %%
# Base Accuracy
y_true, _ = clf_A.get_y_true_pred(corpus, selector=is_ans_labeled)  
cnt = Counter(y_true)
maj_label, maj_count = max(cnt.items(), key=lambda x: x[1])
base_acc = maj_count / sum(cnt.values())
print("Majority label:", maj_label)
print("Base accuracy:", base_acc)
# Out:
# Majority label: ambivalent-reply
# Base accuracy: 0.5916473317865429

# %%
clf_A.accuracy(corpus, selector=is_ans_labeled)
# Out:
# np.float64(0.8474477958236659)

# %%
print(clf_A.classification_report(corpus, selector=is_ans_labeled))
# Out:
#                   precision    recall  f1-score   support
#
# ambivalent-reply       0.86      0.90      0.88      2040
#   clear-nonreply       0.88      0.79      0.83       356
#      clear-reply       0.81      0.76      0.78      1052
#
#         accuracy                           0.85      3448
#        macro avg       0.85      0.82      0.83      3448
#     weighted avg       0.85      0.85      0.85      3448

# %% [markdown]
# Analysis (Condition 1: Pure Answer, No Train/Test Split)
#
# -- Using only the answer text as features, our classifier achieves an accuracy of 0.85, which is notably higher than the base accuracy of 0.59. Precision and recall are relatively balanced across the three classes, though performance is strongest on ambivalent-reply and weaker on clear-reply. This suggests that answer content alone carries useful signals for classification.
#
# -- As a next step, I plan to explore a Condition 2 setting where the question text is concatenated with the answer (Q + A). Adding the question as context may provide richer semantic cues, potentially improving disambiguation between clear-reply and clear-nonreply.

# %% [markdown]
# ## Condition 2: Question + Answer

# %%
# mapping question text to answer text
aq_text = {}
for conv in corpus.iter_conversations():
    for uid in conv.get_utterance_ids(): 
        if uid.startswith("A_"):
            qid = "Q_" + uid.split("_", 1)[1]
            q = corpus.get_utterance(qid)
            aq_text[uid] = (q.text if q and q.text else "")

# %%
# bag-of-words vectors processing: add prefix Q and A to the tokens

re_tok = re.compile(r"\w+")

def qa_prefixed(u):
    if u.meta.get("type") != "answer":  
        return None   # only generate vectors for answer utterances
    
    # find question text
    q_text = aq_text.get(u.id, "") or ""
    a_text = u.text or ""

    # add prefix to distinguish question and answer tokens
    q_tokens = [f"Q_{m.group(0).lower()}" for m in re_tok.finditer(q_text)]
    a_tokens = [f"A_{m.group(0).lower()}" for m in re_tok.finditer(a_text)]

    # concatenate question and answer tokens
    return " ".join(q_tokens + a_tokens)

bow_QA = BoWTransformer(
    obj_type="utterance",
    vector_name="bow_QA_prefixed",
    text_func=qa_prefixed
)
# Out:
# Initializing default unigram CountVectorizer...Done.

# %%
bow_QA.fit_transform(corpus, selector=is_ans_labeled)

# %%
corpus.vectors
# Out:
# {'bow_A', 'bow_QA_prefixed'}

# %%
# check the vector of a random answer
vocab = bow_QA.vectorizer.get_feature_names_out()
import random
u = random.choice([utt for utt in corpus.iter_utterances() if utt.meta.get("type")=="answer"])
vec = u.get_vector("bow_QA_prefixed")

print("Utterance ID:", u.id)
print("Original answer text:", u.text)
print("QA text_func:", qa_prefixed(u))   # 你定义的拼接
# Out:
# Utterance ID: A_685
# Original answer text: Yes, please, go ahead.
# QA text_func: Q_but Q_is Q_it Q_right Q_that Q_they Q_re Q_virtually Q_immune A_yes A_please A_go A_ahead

# %%
# classifier
clf_QA = VectorClassifier(
    obj_type="utterance",
    vector_name="bow_QA_prefixed",
    labeller=lambda u: u.meta.get("coarse_label") if is_ans_labeled(u) else None
)
clf_QA.fit_transform(corpus, selector=is_ans_labeled)
# Out:
# Initialized default classification model (standard scaled logistic regression).
# /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(

# %%
clf_QA.summarize(corpus)
# Out:
#             prediction  pred_score
# id
# A_1967  clear-nonreply    1.000000
# A_1966  clear-nonreply    1.000000
# A_1964  clear-nonreply    1.000000
# A_2063  clear-nonreply    1.000000
# A_825   clear-nonreply    0.999999
# ...                ...         ...
# Q_3443            None         NaN
# Q_3444            None         NaN
# Q_3445            None         NaN
# Q_3446            None         NaN
# Q_3447            None         NaN
#
# [6896 rows x 2 columns]

# %%
clf_QA.accuracy(corpus, selector=is_ans_labeled)
# Out:
# np.float64(0.9904292343387471)

# %%
print(clf_QA.classification_report(corpus, selector=is_ans_labeled))
# Out:
#                   precision    recall  f1-score   support
#
# ambivalent-reply       0.99      0.99      0.99      2040
#   clear-nonreply       1.00      0.98      0.99       356
#      clear-reply       0.99      0.99      0.99      1052
#
#         accuracy                           0.99      3448
#        macro avg       0.99      0.99      0.99      3448
#     weighted avg       0.99      0.99      0.99      3448

# %% [markdown]
# Analysis (Condition 2: Question + Answer, No Train/Test Split)
#
# Using concatenated question–answer representations, the classifier achieved extremely high performance (0.99 precision/recall/F1 across all three classes). This suggests that incorporating the question as context can substantially boost discriminative signal compared to using the answer alone. However, the near-perfect scores are also indicative of potential overfitting, since evaluation was conducted on the same data used for training. To more rigorously assess generalizability, I therefore introduce Condition 3, where I split the dataset into separate train and test sets.

# %% [markdown]
# ## Condition 3: Question + Answer & Split Train and Test Datasets

# %%
from sklearn.model_selection import train_test_split

# %%
# stratified sampling and creating new metadata indicating train and test; still, only answers have labels
answers = [u for u in corpus.iter_utterances() 
           if u.meta.get("type")=="answer" and "coarse_label" in u.meta]
y = [u.meta["coarse_label"] for u in answers]
train_utts, test_utts = train_test_split(answers, test_size=0.2, random_state=42, stratify=y)

for u in train_utts:
    u.meta["split"] = "train"
for u in test_utts:
    u.meta["split"] = "test"

# %%
# selectors
is_answer  = lambda u: u.meta.get("type") == "answer"
is_train_u = lambda u: is_answer(u) and u.meta.get("split") == "train"
is_test_u  = lambda u: is_answer(u) and u.meta.get("split") == "test"

# %%
# bag-of-words vectors processing: add prefix Q and A to the tokens
bow_QA_split = BoWTransformer(
    obj_type="utterance",
    vector_name="bow_QA_prefixed_split",  
    text_func=qa_prefixed                  
)

# learn vocabulary only in train dataset
bow_QA_split.fit(corpus, selector=is_train_u)

# vectorize both train and test dataset
bow_QA_split.transform(corpus, selector=is_answer)
# Out:
# Initializing default unigram CountVectorizer...Done.

# %%
# classifier
clf_QA_split = VectorClassifier(
    obj_type="utterance",
    vector_name="bow_QA_prefixed_split",
    labeller=lambda u: u.meta.get("coarse_label") if is_answer(u) else None
)

# only fit on train dataset
clf_QA_split.fit(corpus, selector=is_train_u)

# create prediction on both train and test dataset
clf_QA_split.transform(corpus, selector=is_answer)
# Out:
# Initialized default classification model (standard scaled logistic regression).
# /Users/byc324/Desktop/24Fall/25Fall/communication/assignment1/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(

# %%
# Evaluation
print("Train accuracy:", clf_QA_split.accuracy(corpus, selector=is_train_u))
print(clf_QA_split.classification_report(corpus, selector=is_train_u))

print("Test accuracy:", clf_QA_split.accuracy(corpus, selector=is_test_u))
print(clf_QA_split.classification_report(corpus, selector=is_test_u))
# Out:
# Train accuracy: 0.994198694706309
#                   precision    recall  f1-score   support
#
# ambivalent-reply       0.99      1.00      1.00      1632
#   clear-nonreply       1.00      0.99      0.99       285
#      clear-reply       0.99      0.99      0.99       841
#
#         accuracy                           0.99      2758
#        macro avg       1.00      0.99      0.99      2758
#     weighted avg       0.99      0.99      0.99      2758
#
# Test accuracy: 0.5507246376811594
#                   precision    recall  f1-score   support
#
# ambivalent-reply       0.65      0.65      0.65       408
#   clear-nonreply       0.44      0.38      0.41        71
#      clear-reply       0.41      0.42      0.41       211
#
#         accuracy                           0.55       690
#        macro avg       0.50      0.48      0.49       690
#     weighted avg       0.55      0.55      0.55       690

# %% [markdown]
# Analysis (Condition 3:  Question + Answer, Train/Test Split)
#
# When evaluated under a proper train–test split, the classifier shows extremely high performance on the training set (accuracy 0.99) but drops sharply on the test set (accuracy 0.55), even underperforming the base accuracy. This indicates severe overfitting: the model memorizes training data but fails to generalize to unseen examples. The gap demonstrates the limitation of the bag-of-words approach and suggests that richer contextual representations or more powerful models (e.g., LLMs) are needed to capture the nuances of question–answer interactions.

# %% [markdown]
# ### ChatGPT 5

# %%
clf_QA_split.summarize(corpus,selector=is_test_u)
# Out:
#               prediction    pred_score
# id
# A_1533    clear-nonreply  9.999426e-01
# A_1729    clear-nonreply  9.999145e-01
# A_1731    clear-nonreply  9.999145e-01
# A_1965    clear-nonreply  9.998740e-01
# A_1616    clear-nonreply  9.996702e-01
# ...                  ...           ...
# A_1817  ambivalent-reply  4.333080e-24
# A_1865  ambivalent-reply  3.361673e-24
# A_2399  ambivalent-reply  1.899436e-24
# A_1796       clear-reply  7.919053e-25
# A_1985  ambivalent-reply  5.797713e-32
#
# [690 rows x 2 columns]

# %%
corpus.random_utterance().meta
# Out:
# {'type': 'answer',
#  'question_order': 2,
#  'label': 'Explicit',
#  'annotator_id': '86',
#  'inaudible': False,
#  'multiple_questions': False,
#  'affirmative_questions': False,
#  'interview_answer_raw': "A couple of points on that—one, the Turks, the Americans, and the Iraqis, including the Iraqi Kurds, share a common enemy in the PKK. And secondly, it's in nobody's interests that there be safe haven for people who are—have the willingness to kill innocent people.A second point I want to make to you, Matt [Matt Spetalnick, Reuters], is that there is a Special Forces presence in northern Iraq, in Kurdistan, now, apart from what you're referring to. In other words— so there is a presence, and there has been a presence for a while.Thirdly, I strongly agree with the sentiments of Secretary Gates, who said that the incursion must be limited and must be temporary in nature. In other words, it shouldn't be long lasting. But the Turks need to move, move quickly, achieve their objective, and get out.",
#  'gpt35_prediction': 'Question part: 1. "How quickly would you like to see Turkey end its offensive, its incursion?"\nVerdict: 2.3 Partial/half-answer\nExplanation: The response acknowledges the need for the Turkish offensive to be limited and temporary in nature and emphasizes the importance of achieving their objective quickly. However, it does not explicitly state the desired timeline for the offensive to end.\n\nQuestion part: 2. "Do you have any concerns about the possibility of protracted presence in northern Iraq causing further destabilization in the region?"\nVerdict: 1.1 Explicit\nExplanation: The response explicitly agrees with Secretary Gates\' view that the incursion must not be long-lasting to avoid further destabilization.',
#  'coarse_label': 'clear-reply',
#  'prediction': np.str_('clear-reply'),
#  'pred_score': np.float64(2.161757214581508e-08),
#  'split': 'train'}

# %%
rows = []
for u in corpus.iter_utterances():
    if u.meta.get("split") == "test" and u.meta.get("type") == "answer":  
        gold = u.meta.get("coarse_label")
        pred = str(u.meta.get("prediction"))
        score = float(u.meta.get("pred_score"))
        rows.append({
            "id": u.id,
            "text": u.text,
            "gold": gold,
            "pred": pred,
            "pred_score": score,
            "correct": gold == pred
        })

# %%
df_pred = pd.DataFrame(rows)

# %%
df_pred
# Out:
#          id                                               text  \
# 0       A_2  Look, I think China has a difficult economic p...
# 1      A_10  We talked about what we talked about at the co...
# 2      A_14  First of all, this trilateral cooperation amon...
# 3      A_17  Let me be clear: I didn't say we didn't guaran...
# 4      A_21  Like I told, we are discussing on DCA, the def...
# ..      ...                                                ...
# 685  A_3424  understand full well that the world expects th...
# 686  A_3435  Because I know Prime Minister Maliki; I know h...
# 687  A_3438  I think the coming election is a referendum on...
# 688  A_3442  See, that's that hypothetical Keil is trying t...
# 689  A_3444  Mike, I believe Iraq will be able to defend, g...
#
#                  gold              pred    pred_score  correct
# 0    ambivalent-reply  ambivalent-reply  8.970231e-05     True
# 1      clear-nonreply  ambivalent-reply  1.837310e-02    False
# 2    ambivalent-reply  ambivalent-reply  4.188193e-10     True
# 3         clear-reply  ambivalent-reply  3.812730e-02    False
# 4    ambivalent-reply    clear-nonreply  9.906355e-01    False
# ..                ...               ...           ...      ...
# 685  ambivalent-reply  ambivalent-reply  1.353469e-01     True
# 686       clear-reply  ambivalent-reply  2.266968e-12    False
# 687       clear-reply  ambivalent-reply  7.055957e-04    False
# 688  ambivalent-reply  ambivalent-reply  1.454134e-01     True
# 689       clear-reply  ambivalent-reply  6.989876e-03    False
#
# [690 rows x 6 columns]

# %%
df_correct = df_pred[df_pred["correct"]]
df_wrong = df_pred[~df_pred["correct"]]

# %%
sample_correct = df_correct.sample(5, random_state=42)
sample_wrong = df_wrong.sample(5, random_state=42)

# %%
test_llm = pd.concat([sample_correct, sample_wrong])
test_llm
# Out:
#          id                                               text  \
# 486  A_2550  It feels bad. [] The toughest thing over the l...
# 477  A_2518  Well, look, I've got a whole bunch of lines in...
# 484  A_2543  Well, I think this is going to be an important...
# 94    A_527  And if you ask him, he will tell you, and he'l...
# 83    A_432  Well, I have real questions about it. Look, th...
# 645  A_3203  Ed, going into Iraq, we were warned about a lo...
# 16     A_87  Let me answer the first question—the first par...
# 98    A_559  I consider firing everybody. [] At some point,...
# 101   A_566  I haven't been told of it yet. I heard there's...
# 40    A_242  Okay. Whoa, whoa, whoa. Hang on, guys. We've o...
#
#                  gold              pred    pred_score  correct
# 486  ambivalent-reply  ambivalent-reply  1.916811e-08     True
# 477       clear-reply       clear-reply  8.035658e-06     True
# 484  ambivalent-reply  ambivalent-reply  1.627012e-08     True
# 94   ambivalent-reply  ambivalent-reply  8.620360e-03     True
# 83   ambivalent-reply  ambivalent-reply  8.614237e-02     True
# 645  ambivalent-reply       clear-reply  6.847671e-03    False
# 16     clear-nonreply       clear-reply  6.373325e-07    False
# 98   ambivalent-reply    clear-nonreply  5.227444e-01    False
# 101    clear-nonreply       clear-reply  4.704690e-01    False
# 40   ambivalent-reply    clear-nonreply  8.191754e-01    False

# %%
aq_text['A_2518']
# Out:
# 'Where is your line in the sand?'

# %%
def build_prompt(q: str, a: str) -> str:
    return f"""You are a careful political Q&A analyst.

Task: Classify the *answer* with respect to the *question* into exactly one of three classes:
- "clear-reply": the answer clearly and directly addresses the question.
- "clear-nonreply": the answer clearly does not address the question (for example, it may refuse to answer, express ignorance, or shift to asking for clarification instead of answering).
- "ambivalent-reply": the answer partially addresses the question or is indirectly related, showing ambiguity or incompleteness (for example, it may be vague, evasive, or only partially relevant).

Return your decision in **strict JSON** with two fields and nothing else:
{{"label": "<one of: clear-reply | clear-nonreply | ambivalent-reply>", "rationale": "<one-sentence explanation>"}}

Question: {q.strip() if q else "(none provided)"}
Answer: {a.strip()}"""

# %%
def make_prompts_df(test_llm, aq_text, build_prompt, csv_path="llm_prompts.csv"):
    def row_to_prompt(row):
        q = aq_text.get(row["id"], "")      
        a = row["text"]
        return build_prompt(q, a)

    out = test_llm.copy()
    out["prompt"] = out.apply(row_to_prompt, axis=1)

    keep_cols = ["id", "prompt", "gold", "pred", "correct"]
    out_to_save = out[keep_cols]

    out_to_save.to_csv(csv_path, index=False, encoding="utf-8")

    return out_to_save

# %%
prompts_df = make_prompts_df(test_llm, aq_text, build_prompt, csv_path="llm_prompts.csv")

# %%
# Out:
# {'A_0': 'How would you respond to the accusation that the United States is containing China while pushing for diplomatic talks?',
#  'A_1': 'Do you think President Xi is being sincere about getting the relationship back on track as he bans Apple in China?',
#  'A_2': " Do you believe the country's slowdown and growth could risk destabilizing the global economy or cause China to be more aggressive defensively, including with Taiwan?",
#  'A_3': ' Are you worried about the meeting between President Putin and Kim Jong Un, if that could mean Russia has more gains in the war in Ukraine?',
#  'A_4': " Is the President's engagement with Asian countries a sign of a cold war mentality?",
#  'A_5': ' Is there a danger of a cold war?',
#  'A_6': 'When will the President meet Mr. Xi?',
#  'A_7': ' How concerned are you about this lack of consensus?',
#  'A_8': ' Concerns about the lack of communication between the interviewee and President Xi of China, and the potential destabilization of the U.S.-China relationship.',
#  'A_9': " Inquiry about the reaction of Kyiv regarding the G-20 communique not naming Russia as the aggressor, and if this issue is becoming divisive with the Global South, and how it impacts the interviewee's commitment to Ukraine.",
#  'A_10': 'What did you talk about with him?',
#  'A_11': ' Are you putting U.S. strategic interests above human rights here in Vietnam?',
#  'A_12': ' Compared to the previous summits, what would be the most significant outcome that President Yoon gained through this summit?',
#  'A_13': 'From the perspective of the people of Korea, what would be the benefit felt from the strengthening of ties?',
#  'A_14': "What kind of shift would there be in President Biden's policy regarding human rights issues and a free and peaceful Korean Peninsula, and what specific solutions does he have in this regard?",
#  'A_15': 'Is Mr. President winning the competition with China?',
#  'A_16': 'ensuring Finland that the U.S. will remain a reliable NATO partner for decades to come.',
#  'A_17': 'Are you worried that the political instability in the U.S. will cause issues in the alliance in the future?',
#  'A_18': ' Concerns about the comments motivating Putin or discouraging him from peace negotiations.',
#  'A_19': ' The risk of the war dragging on for years.',
#  'A_20': ' The possibility of the war ending with Putin still in power.',
#  'A_21': ' Envisioning the possibility of the U.S. having a permanent military base in Finland.',
#  'A_22': "How does the NATOization of Finland change Finland's place in the world?",
#  'A_23': 'NATO membership process',
#  'A_24': 'Does this raise any new concerns about Putin potentially doing more drastic things regarding Ukraine, like nuclear weapons, or potentially against the U.S',
#  'A_25': ' Does the firing of the general and the rebellion by Prigozhin indicate any potential future actions by Putin?',
#  'A_26': 'Tying abortion rights to defense issues and the block on military promotions by Senator Tuberville.',
#  'A_27': 'Would President Biden be willing to talk with Tuberville to find a solution?',
#  'A_28': 'As a leader who shares a border with Russia - What more do you want to see done to deter Putin?',
#  'A_29': 'Working on fortifying the fence along the border between Finland and Russia - Is there anything that concerns you?',
#  'A_30': 'Did the comments about President Xi undermine or complicate the progress made in maintaining a relationship with China?',
#  'A_31': "What is the message to those who say the administration is overlooking the targeting of religious minorities and crackdown on dissent in Prime Minister Modi's country?",
#  'A_32': 'What is your message to those who believe that your administration is overlooking the targeting of religious minorities and a crackdown on dissent in India?',
#  'A_33': 'Republican-led States passing anti-LGBTQ laws and the rise of intimidation and violence against LGBTQ individuals.',
#  'A_34': 'Parents of a transgender girl in Texas considering leaving the State and the country due to safety concerns.',
#  'A_35': 'The U.K. and the U.S. working together to protect elections and democracy from AI-generated disinformation campaigns.',
#  'A_36': 'Regulation of artificial intelligence and how it differs from global efforts to address climate change.',
#  'A_37': "Is today's agreement essentially a recognition that in light of COVID, the growing threat of China, Russia's invasion of Ukraine, that the era of unfettered globalization is over?",
#  'A_38': ' Why do you think the approach of a more interventionist industrial policy, which the U.S. believes is necessary in response to the changing global landscape, is wrong for the U.K.?',
#  'A_39': ' What do you say to those abroad who say that your new Washington consensus is simply a fancier way of saying America first?',
#  'A_40': 'Is the new Washington consensus that you and your National Security Adviser set out simply another way of saying America first, which some overseas think it is?',
#  'A_41': ' Bribery allegations against President Biden',
#  'A_42': 'What do you say to Americans to convince them that they should trust the independence and fairness of the Justice Department?',
#  'A_43': 'How do you address the fact that your predecessor, Donald Trump, repeatedly attacks the Justice Department?',
#  'A_44': ' Concern about accepting a cap or freezing spending and its impact on the economy.',
#  'A_45': "The President's stance on considering both spending cuts and tax revenues.",
#  'A_46': "But you don't think the spending cuts themselves will cause a recession?",
#  'A_47': "President Zelenskyy's communication about the big counteroffensive and whether it is underway or not.",
#  'A_48': 'The reason behind the decision to greenlight the F-16s and the exigency that demands these planes.',
#  'A_49': 'you do expect these F-16s to take part in this conflict?',
#  'A_50': "What assurances do you have that providing F-16s won't escalate this war?",
#  'A_51': 'Russia/U.S. Security Assistance to Ukraine',
#  'A_52': 'Do you think that if there is a breach, nobody is going to blame you?',
#  'A_53': "On the debt limit, you said already, I've done my part.",
#  'A_54': 'Can you speak to your experience?',
#  'A_55': 'Sir, is a congressional deal the only option here, or are you still weighing other unilateral or executive actions?',
#  'A_56': 'How would you respond to criticism that your actions and the G-7 would lead to more instability and division in the world?',
#  'A_57': 'Mr. President, are you still weighing the 14th Amendment, or have you taken those options off the table?',
#  'A_58': "So it's up to lawmakers?",
#  'A_59': "What do you say to those Americans who are watching and aren't convinced?",
#  'A_60': "You've said you can beat Trump again. Do you think you're the only one?",
#  'A_61': "Would you be running if he wasn't?",
#  'A_62': "Did Donald Trump's decision to run affect yours?",
#  'A_63': 'Did President Biden provide you any assurances?',
#  'A_64': 'Did the recent leaks revealing that the U.S. was spying on South Korea come up at all in your discussions?',
#  'A_65': "Regarding President Yoon's statement about strengthening the alliance and investments in cutting-edge industries and science, what will be the long-term impact and direct benefits felt by the public?",
#  'A_66': "Regarding Korean businesses' concerns about the CHIPS Act and the IRA, what message can President Biden send to reassure them?",
#  'A_67': 'Why did you wait so long to implement the agreement for Roxham Road?',
#  'A_68': ' For the 15,000 migrants that Canada will welcome, why so few? What has Canada offered to the U.S. in exchange?',
#  'A_69': "Canada's role in the multilateral forces in Haiti, and what more Canada can do in addition to the $100 million announced",
#  'A_70': 'How confident are you that the problem is contained?',
#  'A_71': 'If it spreads, what measures are you willing or not willing to take?',
#  'A_72': 'Approval of oil drilling in Alaska',
#  'A_73': 'Cancellation of Keystone XL pipeline',
#  'A_74': 'Delay in environmental assessment for Enbridge Line 5 rerouting',
#  'A_75': ' Concerns about something (inaudible)',
#  'A_76': 'Opinion on the Manhattan grand jury potentially indicting the predecessor',
#  'A_77': "Need for a higher cost in response to Iran's targeting of Americans",
#  'A_78': 'How Mexico will be prepared to receive migrants expelled from the United States and the purpose of the new migration center in the southern part of Mexico.',
#  'A_79': 'Concrete actions and impact of the detention of Ovidio Guzmán in relation to fentanyl',
#  'A_80': 'Discussions about energy sector consultations in relation to the USMCA and T-MEC.',
#  'A_81': 'Timeframe and expansion of receiving citizens from Venezuela, Haiti, Cuba, and Nicaragua.',
#  'A_82': 'Amount of technological improvements in the United States.',
#  'A_83': 'Changes in migration policies and the treatment of migrants after the summit.',
#  'A_84': 'On fentanyl?',
#  'A_85': 'energy consultations',
#  'A_86': "After spending 2-plus hours face to face with President Zelenskyy, what you learned or what you took from the meeting that perhaps you couldn't glean or learn in the phone calls or videoconferences.",
#  'A_87': 'Was there any discussion related to the U.S. assessments that Russia would not take escalatory action now that Patriots are being sent, will be delivered—a Patriot battery will be delivered?',
#  'A_88': 'Does that mean that you are ready to grant exception—exemptions of the regulations to European industries?',
#  'A_89': 'Do you think there is a risk of generating divisions?',
#  'A_90': "The journalist's question inaudible.",
#  'A_91': 'Do freight rail workers deserve more than 1 day of paid sick leave',
#  'A_92': "Why didn't President Biden negotiate for paid leave when helping to negotiate the contract?",
#  'A_93': 'What is your approach to talking with President Putin?',
#  'A_94': ' Do you feel realistic that President Zelenskyy is putting a condition to open negotiations and that is the return of Crimea to Ukraine?',
#  'A_95': 'Can a new cold war with China be avoided?',
#  'A_96': 'Do you believe China is preparing, intending to invade Taiwan at some point?',
#  'A_97': 'What warnings did you issue to President Xi if he were to take such action?',
#  'A_98': "Assessing President Xi's posture towards the United States after consolidating power.",
#  'A_99': 'Evaluating whether President Xi was more confrontational or conciliatory and willing to compromise during the meeting.',
#  'A_100': 'What should Americans expect from Congress as it relates to abortion rights after the midterms?',
#  'A_101': 'What should Americans expect from Congress as it relates to abortion rights after the midterms?',
#  'A_102': " What in the next 2 years do you intend to do differently to change people's opinion of the direction of the country, particularly as you contemplate a run for President in 2024?",
#  'A_103': 'Potential impact on peace negotiations',
#  'A_104': 'Claim of Russia evacuating Kherson region and Kherson city',
#  'A_105': 'Can the war continue for quite some time?',
#  'A_106': 'Is there a possibility of a stalemate in the war?',
#  'A_107': 'Criticism of ambitious targets set but lacking implementation and lack of technological and financial transfer from developed to developing nations.',
#  'A_108': 'Asking both leaders about their views on the way ahead on the issue of climate change.',
#  'A_109': 'Will you meet with McCarthy?',
#  'A_110': 'Will you negotiate with them on the debt limit?',
#  'A_111': 'Are you missing in action?',
#  'A_112': 'What is your message to the American people?',
#  'A_113': 'How will you keep that coalition from fraying in 2023?',
#  'A_114': "Elaborate on the President's demeanor and communication style.",
#  'A_115': 'To what extent do you think China has the ability to talk North Korea out of conducting such tests?',
#  'A_116': 'What are the repercussions for U.S.-Chinese relations if a test goes forward?',
#  'A_117': 'Do you think Kevin McCarthy is probably right about Republicans taking back the House?',
#  'A_118': 'Frequency of communication with Mr. McCarthy',
#  'A_119': 'Relationship with Mr. McCarthy',
#  'A_120': 'Opinion on Mr. McCarthy',
#  'A_121': 'The potential impact of Republicans taking control of the House',
#  'A_122': "Message to Republicans considering investigating the family and Hunter's business dealings.",
#  'A_123': ' Do you feel like the fever has broken?',
#  'A_124': 'Do you feel like the election represents a shift towards more decency?',
#  'A_125': 'By end of the year or early next year?',
#  'A_126': " What's your thinking?",
#  'A_127': " Can you tell us what those 'alternative ways forward' are?",
#  'A_128': ' How has Russia responded to those?',
#  'A_129': ' Can you guarantee the elimination of inflation?',
#  'A_130': ' How will you address the costs that exist in the average family and the average Black community?',
#  'A_131': '. What can you promise concretely in these next 2 years that will help turn the pocketbook for the better in the midst of staving off a recession?',
#  'A_132': " What's next in addressing the issue of empathy or the lack thereof in the midst of heated political rhetoric?",
#  'A_133': " Will you tell President Xi Jinping of China that you're committed to defending Taiwan militarily?",
#  'A_134': ' What are you hoping to get out of this meeting that will make it a success?',
#  'A_135': ' Are you willing to make any concessions to him?',
#  'A_136': ' Do you think Elon Musk is a threat to U.S. national security?',
#  'A_137': ' Should the U.S.—and with the tools you have—investigate his joint acquisition of Twitter with foreign governments, which include the Saudis?',
#  'A_138': ' Will aid to Ukraine continue uninterrupted?',
#  'A_139': "How does the sentiment of these Americans factor into the President's decision about whether or not to run for reelection?",
#  'A_140': "What is the President's message to the two-thirds of Americans who do not think he should run for reelection?",
#  'A_141': 'Message to two-thirds of Americans',
#  'A_142': 'Who do you think would be the tougher competitor: Ron DeSantis or former President Trump?',
#  'A_143': 'How is that factoring into your decision?',
#  'A_144': 'Did the respondent think that the other person backed off because of their statement?',
#  'A_145': "What is the respondent's view on what happened?",
#  'A_146': 'Do you think that they are putting together a real alliance, the Chinese and the Russians?',
#  'A_147': "Do you believe that you need to begin speaking with President Xi about some form of arms control if he's going to get up to a level of weapons similar to what the United States and Russia have right now?",
#  'A_148': "How do you explain this to those people who feel the country is going in the wrong direction, including some of the leaders you've been meeting with this week, who think that when you put all of this together, it amounts to an America that is going backward?",
#  'A_149': 'Are you confident that the oil price cap for Russian exports would bring down prices for American drivers?',
#  'A_150': 'How long is it expected for American drivers to continue to pay a premium because of this war?',
#  'A_151': 'Will it bring down prices?',
#  'A_152': 'How long is it fair to expect American drivers and drivers around the world to pay that premium for this war?',
#  'A_153': 'Assurance on F-16 jets for Turkey.',
#  'A_154': 'Do you expect to ask the Crown Prince or the King to increase oil production?',
#  'A_155': 'How will you balance that with your desire to hold them accountable for their human rights abuses?',
#  'A_156': 'But if you were to see the Crown Prince or the King, would you ask them to increase oil production?',
#  'A_157': 'Would you declare a public health emergency as several Democrats are calling on you to do?',
#  'A_158': 'What further specific executive actions are you considering in response to the Roe ruling?',
#  'A_159': 'Discussion of defense budget increase, enemy base strike capability, and Japan-U.S. alliance.',
#  'A_160': ' Analysis of the response to China and the current status of cross-Straits relations',
#  'A_161': 'Should Americans expect something similar to 21-day quarantines for monkeypox?',
#  'A_162': 'Do you think that the U.S. has enough smallpox vaccine stockpiled?',
#  'A_163': 'The question asks if the President is willing to get involved militarily to defend Taiwan, if necessary.',
#  'A_164': 'The benefits of economic security cooperation for the Korean economy and people.',
#  'A_165': 'Whether they would resort to strong export regulations or controls like the United States.',
#  'A_166': 'Regarding the action plan to strengthen the effect of extended deterrence, the question asks about the specific discussions had and whether both sides saw eye to eye on this plan.',
#  'A_167': 'The role of South Korea in improving the representation and advancement of women in a leading world economy.',
#  'A_168': ' What the President and his administration will do to improve gender equality in the country.',
#  'A_169': " Russia's announcement to scale back military operations near Kyiv and another northern city in Ukraine",
#  'A_170': ' The interpretation of this announcement - whether it signifies the end of the war or is an attempt by Russia to buy time and recalibrate for a new military effort.',
#  'A_171': 'Would the U.S. or NATO respond with military action if he did use chemical weapons?',
#  'A_172': 'Have you gathered specific intelligence that suggests that President Putin is deploying these weapons, moving them into position, or considering their use?',
#  'A_173': 'Does President Zelenskyy need to cede any Ukrainian territory in order to gain a ceasefire with Russia?',
#  'A_174': 'Is the idea of ceding Ukrainian territory completely off the table?',
#  'A_175': 'Is it possible that, in expressing that so early, that you were too quick to rule out direct military intervention in this war?',
#  'A_176': 'Could Putin have been emboldened, knowing that you were not going to get involved directly in this conflict?',
#  'A_177': 'Could—if chemical weapons were used in Ukraine, would that trigger a military response from NATO?',
#  'A_178': 'You do not believe that?',
#  'A_179': 'Do you think that getting a firsthand look at the effects of this war on these millions of Ukrainians who have fled their country could change the way that you might respond?',
#  'A_180': ". What makes you think Vladimir Putin will alter course based on the action you've taken today?",
#  'A_181': 'Do you believe the actions today will have an impact on making Russia change course in Ukraine?',
#  'A_182': 'Did President Biden receive assurances from Chancellor Scholz that Germany will pull the plug on the Nord Stream project if Russia invades Ukraine?',
#  'A_183': 'Did President Biden and Chancellor Scholz discuss what the definition of invasion could be?',
#  'A_184': 'Are the sanctions that Chancellor Scholz and the EU are working on, along with the U.S., already finalized or is there still ongoing work?',
#  'A_185': 'No specific title given in the question, but it asks about the preparation and implementation of necessary sanctions in response to potential military aggression against Ukraine.',
#  'A_186': "But what do you—how will you do that exactly, since the project and control of the project is within Germany's control?",
#  'A_187': 'Is Germany a reliable partner to the United States?',
#  'A_188': '. Should NATO act unanimously in delivering heavy weapons to Ukraine, and should Germany, as the strongest European NATO partner, also deliver heavy weapons to Ukraine?',
#  'A_189': ' Should Germany rethink its position on Nord Stream 2 considering the threat posed by Russia?',
#  'A_190': " Is Germany's current positioning on the Russian threat acceptable?",
#  'A_191': 'Are different approaches to arms exports by NATO partners acceptable?',
#  'A_192': 'Will President Putin authorize an invasion of Ukraine before the end of the winter?',
#  'A_193': " What is President Biden's message to the roughly 30,000 Americans currently in Ukraine? Does he think they should leave the country?",
#  'A_194': 'Should Americans who are currently in Ukraine leave the country?',
#  'A_195': 'Specific steps to reduce energy dependence on Russia',
#  'A_196': "Response to suggestions that German reliance on Russian gas limits Europe's options in responding to the crisis in Ukraine",
#  'A_197': 'The role of liquefied natural gas (LNG) as a replacement for Russian pipeline gas',
#  'A_198': ' Inquiring about the belief in an off-ramp for Vladimir Putin.',
#  'A_199': 'Is deescalation still possible given the presence of 100,000 troops at the border?',
#  'A_200': 'Did you overpromise to the American public what you could achieve in your first year in office?',
#  'A_201': 'How do you plan to course-correct going forward?',
#  'A_202': 'Did you overpromise to the American public what you could achieve in your first year in office?',
#  'A_203': 'How do you plan to course-correct going forward?',
#  'A_204': 'Do you need to be more realistic and scale down these priorities in order to get something passed?',
#  'A_205': 'Is there anything that you are confident you can get signed into law before the midterm elections?',
#  'A_206': 'Some Republicans who may be open to major changes on voting rights—for instance, like Mitt Romney—he says he never even received a phone call from this White House. Why not?',
#  'A_207': "If this voting rights legislation isn't passed, do you still believe the upcoming election will be fairly conducted and its results will be legitimate?",
#  'A_208': 'What can your administration do to help make up for learning loss for students?',
#  'A_209': 'What do you say to those teachers and principals and parents about school closings?',
#  'A_210': 'Concerns about the lack of unity among European allies regarding sanctions against Russia and the potential loss of leverage over Vladimir Putin.',
#  'A_211': 'Doubts about the effectiveness of sanctions in deterring Putin and why the threat of new sanctions would make him pause.',
#  'A_212': 'Do you still think that the last thing Putin wants is a Cold War?',
#  'A_213': 'Has your view of Putin changed in the past few months, considering the recent developments in Ukraine?',
#  'A_214': ' If Putin does invade Ukraine, will the US revert to a containment policy?',
#  'A_215': 'Space for the mentioned proposals.',
#  'A_216': 'Moving nuclear weapons out of Europe and troop rotations in the old Soviet bloc',
#  'A_217': 'Off-ramp and assurance about NATO membership and nuclear weapons in Ukraine.',
#  'A_218': "How long should Americans expect to face higher prices when they're at the grocery store or when they're at the gas pump? Is this something that they're going to see into the summer, into next fall?",
#  'A_219': "But isn't that an acknowledgment that you're limited in what you can do if you're relying on the Fed to make decisions and you're unable to get a Build Back Better proposal through, aren't you simply limited in what you can do to deal with inflation?",
#  'A_220': 'How does the President think the report card looks right now?',
#  'A_221': "Is it fair to look at the midterm elections as a report card on the President's progress on inflation, border security, and standing up to Russia?",
#  'A_222': ' Can you tell us who those five Republican Senators are?',
#  'A_223': 'At your first press conference, 10 months ago, I asked you if there was anything you could do beyond legislation to protect voting rights. Now that legislation appears to be hopelessly stalled, can you now lay out your strategy to protect voting rights?',
#  'A_224': 'Can you specifically lay out the executive orders and other actions you can take to protect voting rights?',
#  'A_225': ' Is it because the numbers of fully vaccinated Americans would suddenly look a lot less impressive?',
#  'A_226': "Why hasn't this White House changed the definition of fully vaccinated to include the third booster shot?",
#  'A_227': 'The question is asking if the definition will be changed',
#  'A_228': 'Are you saying that a minor incursion by Russia into Ukrainian territory would not lead to the sanctions that you have threatened?',
#  'A_229': 'Or are you effectively giving Putin permission to make a small incursion into the country?',
#  'A_230': "Has this administration, have you determined whether President Putin plans to invade or move into Ukraine, as you've said?",
#  'A_231': ' Black voters feeling that the President is not fighting hard enough for them and their priorities.',
#  'A_232': "Are you satisfied with Vice President Harris' work on voting rights?",
#  'A_233': 'Can you guarantee that Vice President Harris will be your running mate in 2024, if you decide to run again?',
#  'A_234': "Inquiring about the President's willingness to provide further explanation.",
#  'A_235': 'What do you say to those who are offended by your speech?',
#  'A_236': 'Is this country more unified than it was when you first took office?',
#  'A_237': 'Is the country more unified than when you first took office?',
#  'A_238': 'Are you satisfied with your team here at the White House, sir?',
#  'A_239': 'Why are you trying so hard in your first year to pull the country so far to the left?',
#  'A_240': '2) Opinion on the potential illegitimacy of the elections.',
#  'A_241': 'Did you expect that that would work with Senators Manchin or Sinema—that argument?',
#  'A_242': ' What does the new normal look like?',
#  'A_243': ' Virtual summit participation',
#  'A_244': ' What did you say to the Chinese President?',
#  'A_245': ' Is there a reason your press staff was unaware of that?',
#  'A_246': ' How the President plans to end the war in Yemen.',
#  'A_247': ' Whether the administration will put the Houthi rebels or militias back on the terror list.',
#  'A_248': 'addressing the tension between accomplishing big things and unifying the country.',
#  'A_249': ' Are you considering a summit with Vladimir Putin to address concerns and seek a resolution?',
#  'A_250': ' How concerned are you about the potential for a NATO-Russia confrontation if Russia invades Ukraine and the conflict escalates?',
#  'A_251': 'Based on your conversations with your health advisers, what type of restrictions do you imagine being on Americans this time next year?',
#  'A_252': 'What does the new normal look like for social gatherings and travel to you?',
#  'A_253': "How do you plan to win back moderates and Independents who cast a ballot for you in 2020 but, polls indicate, aren't happy with the way you're doing your job now?",
#  'A_254': ' Lack of access to the vaccine for young children under the age of 5.',
#  'A_255': 'When access to the vaccine for young children might change.',
#  'A_256': 'What is your message for residents in the country who are struggling with high gas prices, grocery store prices, and pharmacy costs?',
#  'A_257': "Are you planning on traveling to South America and other countries in the Western Hemisphere given China's influence in the region?",
#  'A_258': "The question asks about the similarity between the GOP's obstructionist tactic during Biden's Vice Presidency and their expected treatment of him as President.",
#  'A_259': 'The question asks why Biden thought the GOP would treat him differently than they treated Barack Obama during his Vice Presidency.',
#  'A_260': 'Could school reopenings or closures become a potent midterm issue for Republicans to win back the suburbs?',
#  'A_261': 'Why did you tell Jeff [Jeff Zeleny, CNN] that you were satisfied with your team? Why are you not willing to make or interested in making any changes, either at the CDC or other agencies, given the fact that the messages have been so confusing?',
#  'A_262': 'You campaigned on canceling $10,000 in student loans. Do you still plan to do so and when?',
#  'A_263': "Now that you've clarified the Bull Connor comments, do you plan to reach out to Republicans like Mitt Romney to talk about reforming the Electoral Count Act?",
#  'A_264': "Inquiring about the President's concern regarding the growth of the potential for armed conflict with China.",
#  'A_265': "Assessing the current state of U.S.-China relationships after the President's first 10 months in office, considering difficulties in diplomatic engagement, Chinese military activities, and the potential for armed conflict.",
#  'A_266': 'When specifically should Americans expect prices to come down?',
#  'A_267': 'The mention of high inflation in the U.S.',
#  'A_268': 'The impact of rising prices on everyday items.',
#  'A_269': "Have you decided who you will nominate to chair the Federal Reserve Board? And if not, can you speak a little bit about what you're thinking about as you consider your choice for Fed Chair and the other seats that are open?",
#  'A_270': "This is the latest that a President has gone without nominating somebody the year before a nominee needs to be selected. And are you concerned about potentially having a short timeline, especially if you're not going to renominate Jay Powell?",
#  'A_271': 'Do you see—do you see his problems as a rebuke of your Presidency?',
#  'A_272': 'And could this signal your real losses for Democrats in the midterms?',
#  'A_273': 'Climate activists feeling skeptical and angry about broken promises and the insufficiency of current goals.',
#  'A_274': "The anger towards the conference and doubts about climate legislation passing due to Joe Manchin's position and the conservative Supreme Court's examination of EPA's authority.",
#  'A_275': 'The concern that current efforts are not enough to address the climate crisis and the request for a message to those worried about the situation.',
#  'A_276': "Can the world and others be confident that you will be able to follow or make good on the promises on climate change that you have made, when you're at Glasgow, without a vote having taken place on your bill?",
#  'A_277': 'Some NGOs are already saying that the G-20 commitments today were underwhelming. How do you respond to their criticism that the G-20 response is not a good sign for COP26?',
#  'A_278': "Do you see any irony in pushing them to increase oil production at the same time that you're going to COP26 to urge people to lower emissions?",
#  'A_279': 'What steps are you considering taking if OPEC Plus does not raise supply?',
#  'A_280': 'Why not allow even middle class people around the world to pay more for gasoline in the hope that they would consume fewer fossil fuels and emit less?',
#  'A_281': 'Why do you think workers have not returned to the labor force in America as fast as your administration thought they would?',
#  'A_282': "Why aren't people coming back to work?",
#  'A_283': 'What costs are you prepared to impose on Iran if it continues to carry out attacks against the United States, such as the recent drone strikes against U.S. forces in Syria?',
#  'A_284': 'How will you determine whether the Iranians are serious about rejoining the nuclear talks, as they have indicated they will do by the end of November?',
#  'A_285': 'Can you definitively say that you will still meet the goal of reducing emissions by 50 percent by 2030?',
#  'A_286': 'Does what Pope Francis told you put this debate to rest?',
#  'A_287': 'What does it mean for the Catholics back home to hear Pope Francis call you a good Catholic in the middle of this debate about denying you the sacrament of Communion?',
#  'A_288': 'Business advisory for Hong Kong',
#  'A_289': 'Build Back Better agenda and Senators Manchin and Sinema',
#  'A_290': "Regarding the points asked in the German reporter's question",
#  'A_291': 'The reporter asks President Biden to explain why there is still a travel ban for people coming from Germany or other states of the European Union while people from Turkey, where the number of new cases is seven times as high, can come.',
#  'A_292': 'The reporter asks Chancellor Merkel about her main argument to work for a lifting of the travel ban and whether she has had success with this.',
#  'A_293': 'What were the consequences that the President threatened?',
#  'A_294': "What is something concrete that the President achieved today to prevent Russia's interference in elections from happening again?",
#  'A_295': 'What did you say would happen if opposition leader Alexei Navalny dies?',
#  'A_296': "Mr. Putin's role as a disrupter of NATO and the United States",
#  'A_297': "Penalties for interfering in critical infrastructure and Putin's response",
#  'A_298': "Agreement with President Putin's statement regarding the absence of threats or scare tactics",
#  'A_299': 'Reasons for the shortened duration of the summit',
#  'A_300': 'Did you touch on Afghanistan and the safe withdrawal of troops?',
#  'A_301': 'Whether there were any threats issued.',
#  'A_302': 'Can you share what you asked him about Afghanistan? What was your particular request for Afghanistan and the U.S. troops?',
#  'A_303': 'How will you measure success, especially when it comes to these working groups on Russian meddling and on cybersecurity?',
#  'A_304': 'Were there any ultimatums made when it comes to ransomware?',
#  'A_305': 'Follow-up question request',
#  'A_306': "Response to President Putin's statement regarding cracking down on opposition leaders and the comparison to events like January 6 and Black Lives Matter.",
#  'A_307': " President Putin's satisfaction with the comment about him being a killer",
#  'A_308': "The reporter's request for the President's side on the matter",
#  'A_309': "And now that you've talked to him, do you believe you can trust him?",
#  'A_310': 'After your talks with President Putin, how interested do you think he is in improving the media climate in Russia?',
#  'A_311': 'Did military response ever come up in this conversation today? Did you—in terms of the red lines that you laid down, is military response an option for a ransomware attack?',
#  'A_312': "And President Putin had called you, in his press conference, an experienced person. You famously told him he didn't have a soul. Do you now have a deeper understanding of him after this meeting?",
#  'A_313': 'Military response',
#  'A_314': ' Asking President Xi to open up China to WHO investigators regarding COVID-19',
#  'A_315': "Americans' expectations and a successful outcome of the meeting",
#  'A_316': " The President's approach and mindset when meeting with Vladimir Putin, given his previous interactions with him",
#  'A_317': 'Concerns from world leaders about meeting with President Putin early in the Presidency and it being perceived as a reward.',
#  'A_318': ' If he does choose to cooperate, how would you ever trust him?',
#  'A_319': "What is your version of 'trust but verify'?",
#  'A_320': 'What the President has been saying to allies about how the next President of the United States can keep any promises made',
#  'A_321': "Why are you not having a joint press conference with Putin during the summit? Why not take the chance to call out Russia's disruptive actions in front of the world?",
#  'A_322': 'In what concrete ways could your summit with Vladimir Putin change the currently low U.S.-Russia relations?',
#  'A_323': "What can be done to change some of China's actions?",
#  'A_324': " Why isn't the G-7 communiqué on China as tough as the interviewer and their team wanted it to be and are they disappointed in that?",
#  'A_325': 'Are you satisfied with what came out in the communiqué?',
#  'A_326': 'action on China?',
#  'A_327': 'What do you think China needs to do to ease tensions?',
#  'A_328': ' Is it actually realistic to end the pandemic by 2022?',
#  'A_329': 'Will the U.S. commit to send additional doses overseas?',
#  'A_330': ' How are you going to bridge that gap?',
#  'A_331': "The U.S. has been slapping sanctions on Russia for years for its malign activities, and Russia has not stopped. So what specifically will you do differently to change Vladimir Putin's behavior?",
#  'A_332': "Asking for an analysis of why his behavior hasn't changed despite U.S. actions",
#  'A_333': 'Are you open to a trade with Vladimir Putin where Russia would hand over cyber criminals to the United States if the U.S. would do the same to Russia and an agreement came out of their meeting?',
#  'A_334': 'What are those preconditions?',
#  'A_335': ' And do you believe he would ever be able to meet them?',
#  'A_336': "Is that it? I think there's one more question over here.",
#  'A_337': 'Do you have certain expectations that he will bolster the rights of the Palestinian people in some way?',
#  'A_338': 'Did you convey that to him in your conversations?',
#  'A_339': ' What is your relationship like now with Israeli Prime Minister Benjamin Netanyahu?',
#  'A_340': 'News on vaccine cooperation and achievements:',
#  'A_341': 'Asking President Biden if there is time for one more question.',
#  'A_342': 'What do you think the unidentified aerial phenomena that President Obama mentioned are?',
#  'A_343': "Russia's aggression in Ukraine and Japan's role",
#  'A_344': 'The significance of the trilateral relationship between Japan, U.S., and R.O.K.',
#  'A_345': "North Korea's nuclear missile development and the significance of the partnership between Japan, South Korea, and the U.S.",
#  'A_346': "The release of treated water at Fukushima Daiichi nuclear power plant and Prime Minister Kishida's explanation",
#  'A_347': "Prime Minister Kishida's intent to respect the IAEA report and the reason for supporting the policy of the Kishida administration",
#  'A_348': "China's threat in Asia and the comment made by Prime Minister Kishida",
#  'A_349': 'How should world leaders, both good and bad, view this moment both for America and for your Presidency?',
#  'A_350': "How do you interpret last night's results in terms of deciding whether you want to seek another term?",
#  'A_351': 'Is it now more likely that you will run?',
#  'A_352': "What's going to be your timeline for consideration?",
#  'A_353': "Are you changing your calculation in terms of the pace and kind of assistance to Ukraine, considering President Zelenskyy's assessment that the war needs to end before the winter?",
#  'A_354': "Do you share the view that some of the tariffs on Chinese imports impose more harm on consumers and businesses and aren't very strategic?",
#  'A_355': 'Are you considering taking down some of those tariffs?',
#  'A_356': 'Transparency on the coronavirus origins',
#  'A_357': 'The questioner asks if there is a need to reprioritize the agenda.',
#  'A_358': 'How far are you willing to go to achieve those promises that you made to the American people?',
#  'A_359': 'Should it take 60 votes or 51 votes to end a filibuster on legislation?',
#  'A_360': "Is the messaging of allowing children to stay in the country encouraging families like Yossell's to come?",
#  'A_361': 'Do you want to see these unaccompanied minors staying in this country?',
#  'A_362': 'Should they be deported eventually?',
#  'A_363': 'Reaction to the images from the facility',
#  'A_364': "Acceptability of what's happening inside",
#  'A_365': 'When the issue will be fixed',
#  'A_366': 'Commitment to have no U.S. forces in Afghanistan by May 2.',
#  'A_367': 'Will you commit to transparency on this issue, Mr. President?',
#  'A_368': 'How soon will journalists be able to have access to the facilities?',
#  'A_369': 'How soon will that be, Mr. President?',
#  'A_370': 'Whether the rollbacks were done too quickly.',
#  'A_371': 'Responsibility for everything happening at the border now.',
#  'A_372': 'Did you move too quickly to roll back some of the Executive orders of your predecessor?',
#  'A_373': ' What is your red line on North Korea?',
#  'A_374': " What actions will you take regarding North Korea's missile tests?",
#  'A_375': 'Is that how the crisis in North Korea is assessed?',
#  'A_376': 'Can you define what you mean by diplomacy?',
#  'A_377': 'Is there anything else you can do about it besides passing legislation?',
#  'A_378': 'Should the filibuster be abolished?',
#  'A_379': 'If not, why not?',
#  'A_380': "It sounds like you're moving closer to eliminating the filibuster. Is that correct?",
#  'A_381': "Is that a 'yes' that you are running for reelection?",
#  'A_382': 'Will Vice President Harris be on your ticket if you do run?',
#  'A_383': ' Are you more likely than you were when you came into office to maintain tariffs on China?',
#  'A_384': 'Are you considering banning imports of forced-labor products?',
#  'A_385': 'Would you consider cutting off U.S. investment or Chinese access to international payment systems?',
#  'A_386': 'Expectations for improved contact, expediency, and processing at the border.',
#  'A_387': 'How do you realistically and physically keep these families from coming to the U.S. when things will not get better in their countries right away?',
#  'A_388': 'Have you had any talks with Senate Republicans who are threatening this administration with not considering the immigration legislation that was passed in the House until the situation at the border has been resolved?',
#  'A_389': ' Do you hope that Amy Coney Barrett is watching as well?',
#  'A_390': 'Democrats are arguing that ACB puts in danger not only Roe v. Wade but a number of other decisions. Do you think that they are correct?',
#  'A_391': 'Do you really believe that Joe Biden will be on any type of performance-enhancing drug ahead of the debates?',
#  'A_392': 'Or are you just joking?',
#  'A_393': 'Who has said that aside from you, sir?',
#  'A_394': 'Who has said that, sir?',
#  'A_395': " Is it more or less than '16?",
#  'A_396': 'Confirmation of prior knowledge of the release date.',
#  'A_397': 'Do you anticipate Joe Biden being held to task?',
#  'A_398': 'Will he be able to answer those questions at the debate?',
#  'A_399': "To follow on that, if he tries to dodge the questions or doesn't address them head on, are you prepared with the facts and information to answer that for the American people?",
#  'A_400': "What's your comment on this?",
#  'A_401': 'Meeting with Barbara Lagoa',
#  'A_402': 'Do you plan to meet with Barbara Lagoa in Washington?',
#  'A_403': 'Is she still on your shortlist?',
#  'A_404': 'Governor of Missouri testing positive for coronavirus.',
#  'A_405': 'charges in the Breonna Taylor case.',
#  'A_406': "the determination of the President's stance on the FDA considering stricter guidelines for the emergency authorization of a COVID vaccine",
#  'A_407': 'The emergency phone call',
#  'A_408': ' Question about Breonna Taylor',
#  'A_409': ' Why not a year ago?',
#  'A_410': 'Why not 2 years ago?',
#  'A_411': 'Why not 3 years ago?',
#  'A_412': ' Why 46 days to the election?',
#  'A_413': 'Timeline confirmation',
#  'A_414': 'The Commerce Department essentially gave you a runway today to strike a deal after the election. Do you expect the TikTok deal before the election?',
#  'A_415': ' Do you expect the TikTok deal after the election?',
#  'A_416': 'In your discussions with the Kuwaitis today, have you discussed where they stand this week as we go into the U.N., as the United States tries to extend sanctions on Iran?',
#  'A_417': "What's a scam?",
#  'A_418': "What's a scam?",
#  'A_419': ' Voting by mail is a scam?',
#  'A_420': " Don't your officials vote by mail, sir?",
#  'A_421': 'Are they part of the scam?',
#  'A_422': 'What would be a timeline that you would be happy with?',
#  'A_423': ' So when do you want to see it available?',
#  'A_424': 'Seeking confirmation and clarification about the availability of 700 million doses by the end of Q1.',
#  'A_425': 'Asking about the timeline for the availability of the vaccine.',
#  'A_426': 'Inquiring about the vaccination plan for low-priority individuals.',
#  'A_427': "Are you prepared to sign off on the Oracle and TikTok deal, even though the Treasury isn't getting paid?",
#  'A_428': ' Does the deal meet your requirements in terms of national security concerns?',
#  'A_429': 'Payment',
#  'A_430': "Allies' interest in standing with the administration in taking action against forced labor imposed by the Communist Party.",
#  'A_431': "The Chinese Communist Party's response to the limited ban on certain products from Xinjiang due to the use of slave labor.",
#  'A_432': 'Should the U.S. remain part of the WTO?',
#  'A_433': 'What was his response?',
#  'A_434': 'Did he acknowledge that?',
#  'A_435': 'The question asks if the interviewee wants to reverse what they previously told Woodward about the 13- to 14-month timeline for a vaccine.',
#  'A_436': '——$500 billion for the States?',
#  'A_437': "In terms of things that you don't agree, are you comfortable with the $500 billion?",
#  'A_438': 'Would you endorse that proposal?',
#  'A_439': "Wouldn't this be more effective than a vaccine and help schools and the economy?",
#  'A_440': 'Why not devote energy to a campaign to have all Americans wear a mask?',
#  'A_441': 'Why not wear it more often or have the White House staff wear it more often?',
#  'A_442': 'Why not set an example for the country?',
#  'A_443': 'Can you talk us through a bit more on the focus on distributing to minorities and how that would work?',
#  'A_444': 'What was driving the increase in wealth for African Americans?',
#  'A_445': 'What would be the plan for the second term to improve lives for African Americans?',
#  'A_446': "How can the American people trust you on the pandemic when you're contradicting the head of the CDC in your own administration?",
#  'A_447': 'Were you informed about positive coronavirus cases in the White House today?',
#  'A_448': 'Were you informed about coronavirus cases—positive cases—in the White House today?',
#  'A_449': 'Were you informed about coronavirus cases—positive cases—in the White House today?',
#  'A_450': 'How many people?',
#  'A_451': 'How many?',
#  'A_452': 'Were they yesterday at the event?',
#  'A_453': 'How many?',
#  'A_454': 'Mr. President, how many people?',
#  'A_455': 'Was it at the event last night?',
#  'A_456': 'Why did you lie to the American people?',
#  'A_457': 'Why should we trust what you have to say now?',
#  'A_458': 'Should people trust you now?',
#  'A_459': ' Why did you, as President of the United States, not level with the American people?',
#  'A_460': 'Why did you not share the information that you knew at the time, in real time?',
#  'A_461': 'You knew it was airborne. You knew—on February 7, you told Bob Woodward how it transferred from person to person in the air, how deadly it was. Why did you not come to the podium and calmly tell the people what to expect?',
#  'A_462': '[Inaudible]—put that out in February?',
#  'A_463': 'Where is that?',
#  'A_464': 'Do you have confidence in the investigation?',
#  'A_465': 'Do you want to see more indictments?',
#  'A_466': ' Do you think there should be more indictments as a part of this investigation?',
#  'A_467': ' Is speaking louder better?',
#  'A_468': 'Have you asked John Kelly to refute that story?',
#  'A_469': 'Should the police be allowed to use nonlethal force to quell the violence in their cities?',
#  'A_470': 'Why have you not met with them in person?',
#  'A_471': 'Are you okay with Postmaster General DeJoy asking former employees at his private company to make donations to the GOP and then reimburse them?',
#  'A_472': ' Would you support an investigation?',
#  'A_473': ' Whether the President thinks someone should lose their job if it is proven they were involved in a campaign finance scheme.',
#  'A_474': 'Would the President support canceling the Nord Stream 2 pipeline?',
#  'A_475': ' Have you asked John Kelly to publicly refute the Atlantic?',
#  'A_476': 'May I finish?',
#  'A_477': 'May I finish the question?',
#  'A_478': "Aren't you also saying that for political reasons?",
#  'A_479': 'Do you object to slavery itself being taught in schools?',
#  'A_480': 'Why do you object to that being taught in schools?',
#  'A_481': 'Can I ask a question on the vaccine?',
#  'A_482': "Is it correct that you're waiting for Congress?",
#  'A_483': 'Would Kimberly, Don Jr., and Ivanka Trump, who are very popular among Indian Americans, be campaigning on your behalf around the Indian Americans with your views on the India and U.S. relationship?',
#  'A_484': 'Do you think Indian Americans are voting for you?',
#  'A_485': 'Are they supporting you?',
# ...
#  'A_809': "Question on the coronavirus: What do you say to Americans who say, How can you keep me safe? How can you reopen the government, if even the Vice President is self-isolating? And why hasn't testing gotten up to the point where every American who wants to test can get a test?",
#  'A_810': 'Delay in embracing widespread testing',
#  'A_811': 'Motive behind the delay in embracing widespread testing',
#  'A_812': 'Why do you believe that their motive is politics rather than public safety?',
#  'A_813': " How do you respond to criticism that you're also motivated by politics to try to grow the economy ahead of the election?",
#  'A_814': 'Is there anything else the administration is planning to do to get these new cases under control?',
#  'A_815': 'Or is this just a fact of life?',
#  'A_816': 'Do you agree with those models?',
#  'A_817': 'Is that your expectation as well?',
#  'A_818': 'Do you agree with the models projecting 130,000 cases through August?',
#  'A_819': ' Why not just mandate that?',
#  'A_820': ' Have you considered that?',
#  'A_821': ' Why not require that?',
#  'A_822': 'Are you now, or are you considering, separating some more with Vice President Pence as a precautionary measure?',
#  'A_823': 'Do you believe the Justice Department should prosecute him?',
#  'A_824': ' What crime exactly are you accusing President Obama of committing?',
#  'A_825': 'Why does that matter?',
#  'A_826': "Why is this a global competition to you if, every day, Americans are still losing their lives and we're still seeing more cases every day?",
#  'A_827': ' Do you want to follow up?',
#  'A_828': 'Sir, why are you saying that to me, specifically? That I should ask China?',
#  'A_829': 'Can I ask you a question, please?',
#  'A_830': 'Why is it the correct time to do this now in the middle of a pandemic?',
#  'A_831': 'Would you consider taking away their Federal funding?',
#  'A_832': ' Will it exist by May 1?',
#  'A_833': 'Will you support the WHO again if Tedros is immediately replaced?',
#  'A_834': 'Do you want to see Tedros step down as a possible reform?',
#  'A_835': ' Criticizing the WHO for praising China as transparent',
#  'A_836': ' Square the decision to revoke funding',
#  'A_837': 'May 1 deadline?',
#  'A_838': "Permission to follow-up on Jordan's question.",
#  'A_839': " Pointing out the President's previous praise for China in January regarding their transparency about the coronavirus.",
#  'A_840': ' When will we have that?',
#  'A_841': 'Do you have any-[inaudible]?',
#  'A_842': ' Assurance to workers who are asked to go back to work, but are fearful of doing so.',
#  'A_843': ' Larry Kudlow said the Paycheck Protection money will run out soon and the plan to replenish it is stalled in Congress.',
#  'A_844': ' What can the President do to try to move the plan forward?',
#  'A_845': ' What the President plans to do about it.',
#  'A_846': " United Nations economist's warning about the potential interruption of the food supply during the pandemic.",
#  'A_847': 'The potential number of additional American deaths if guidelines are eased.',
#  'A_848': 'How are you doing, sir?',
#  'A_849': "Like what, sir, if you wouldn't mind?",
#  'A_850': 'Contact with the Brazilian President, Bolsonaro, after a member of his delegation tested positive.',
#  'A_851': ' Precautionary measures to protect the President and his staff who were with Senators Lindsey Graham and Rick Scott.',
#  'A_852': '. Are you in contact with him over the coronavirus crisis?',
#  'A_853': ' Do you take responsibility for the lag in testing?',
#  'A_854': "What's the date of that?",
#  'A_855': 'When can you guarantee that every single American who needs a test will be able to have a test?',
#  'A_856': 'Would you consider adding them to this travel ban list?',
#  'A_857': 'Why do they, Mr. President, deserve an exemption?',
#  'A_858': 'Do you see the data China has been sharing with the United States has been helpful?',
#  'A_859': 'How much confidence does this give you to control the virus in the United States?',
#  'A_860': 'Did you discuss the potential closing of the border between Canada and the U.S.?',
#  'A_861': 'Are you considering ways to salvage the $2 billion daily trade between the two countries?',
#  'A_862': ' Mr. President, as a relatively new Floridian, what is your message today to the cruise line industry and the travel industry that Florida depends upon?',
#  'A_863': "Since Senator Rick Scott and Miami-Dade Mayor Carlos Giménez have the same exposure as you and are self-isolating, what's your message to them, that they shouldn't be?",
#  'A_864': 'How do you see the overall progress that Asian countries made?',
#  'A_865': 'When can we expect that announcement?',
#  'A_866': "onfirmation of Dr. Fauci's presence and acknowledgment of understanding",
#  'A_867': 'Have the Chinese officials signaled any resistance to upcoming trade talks in response to how the virus is being handled?',
#  'A_868': 'What is the response to the Chinese officials expressing discontent over the source of the virus and spinning narratives?',
#  'A_869': '[Reorganization at the National Security Council]',
#  'A_870': 'Should Americans feel safe or should Americans at all be traveling to states such as Washington State, New York, and other hotspots within this country?',
#  'A_871': "Comparison between self-quarantine for Americans returning from Europe and the President's encounter with someone who now has coronavirus from Brazil.",
#  'A_872': 'Domestic travel',
#  'A_873': 'In light of the rising cases, are you changing your mind about the UK doing a good job in tackling coronavirus?',
#  'A_874': 'Have you discussed when these travel restrictions might be put in place?',
#  'A_875': 'Are you going to be?',
#  'A_876': 'When do you think that will happen?',
#  'A_877': 'Will you let us know the results?',
#  'A_878': 'When do you expect to see items like hand sanitizer back on the shelves?',
#  'A_879': 'Is there a potential bailout for the cruise industry? If so, is it still being considered and how much would it be?',
#  'A_880': 'Are you considering other travel restrictions?',
#  'A_881': 'Should they go on with their daily lives? Change their routine? What should they do?',
#  'A_882': 'How should Americans prepare for this virus?',
#  'A_883': 'Are you worried about the U.S. troops in South Korea now?',
#  'A_884': "When you did use the word hoax, couldn't that cause some people to not take the precautionary steps because they are linking what you're saying, when you use the word hoax, in the context of coronavirus?",
#  'A_885': "What responsibility do you feel, as you're communicating about this, for the public to follow your directions and to take the prudent steps?",
#  'A_886': 'Precautions regarding travel to avoid contact with the virus',
#  'A_887': 'Precautions regarding meeting people to avoid contact with the virus',
#  'A_888': 'Did you get a flu shot?',
#  'A_889': 'Why are you renominating Congressman John Ratcliffe?',
#  'A_890': 'Does this mean the war in Afghanistan is over?',
#  'A_891': 'Is the Taliban in charge?',
#  'A_892': ' Is the U.S. Government considering evaluating similar measures in the U.S. in case the situation gets worse?',
#  'A_893': 'Why are you considering closing the border with Mexico, since there are so many more cases here than there?',
#  'A_894': 'Are you working with the governments from Brazil and Mexico to try to coordinate a response about this? Or did you talk to President Bolsonaro?',
#  'A_895': 'Should have never gone into Afghanistan?',
#  'A_896': 'Is that enough—that kind of a letter?',
#  'A_897': " What's your reaction?",
#  'A_898': 'What powers will you use to speed it up?',
#  'A_899': 'Confirming if both topics will be discussed.',
#  'A_900': "The guarantee that political considerations and ideological issues will play no role in the Government's response to the virus.",
#  'A_901': 'Are you in talk with Turkish Government regarding this topic?',
#  'A_902': ' Impact of people stopping traveling.',
#  'A_903': 'Impact of supply chain interruptions.',
#  'A_904': 'How can you say that the markets are strong?',
#  'A_905': 'Global Coronavirus Outbreak/Potential Travel Restrictions/Domestic Containment Efforts',
#  'A_906': 'Are you planning on adding Italy and South Korea to the list of countries with travel restrictions?',
#  'A_907': ' Are you considering restricting travel to and from South Korea, Italy, and other countries that have been affected by this?',
#  'A_908': 'The reason for selecting the Vice President to lead the response.',
#  'A_909': 'What can you do about that?',
#  'A_910': ' If the CDC is right in saying that the spread is inevitable, are you going to be dealing with stock market issues and economy issues for some time to come here?',
#  'A_911': '. How much are you willing to give?',
#  'A_912': " How much money are you willing to give Congress if they're going $6 billion more than you've offered?",
#  'A_913': 'Should Americans be going out getting protective equipment such as masks and so forth?',
#  'A_914': 'And if so, what is the U.S. doing to boost production of masks?',
#  'A_915': "What is your response to Speaker Pelosi who said earlier today you don't know what you're talking about, about the coronavirus?",
#  'A_916': "Do you want to address critics who say you can't be trusted about what your administration is saying?",
#  'A_917': ' Is it your opinion or is it your contention that if people have an opinion contrary to yours, that they should be sued?',
#  'A_918': 'Clarification of whether the statement made is an opinion.',
#  'A_919': 'Tokyo hosting the Summer Olympic Games in July – Do you expect Tokyo will be able to successfully host the games?',
#  'A_920': 'Should U.S. schools be preparing for a coronavirus spreading?',
#  'A_921': 'Are financial markets overreacting here?',
#  'A_922': 'Are you suggesting that that was overblown?',
#  'A_923': "You don't think the sell-off had to do with the coronavirus—[inaudible]?",
#  'A_924': 'Travel restrictions regarding China.',
#  'A_925': 'Does this experience at all give you pause about those consistent cuts?',
#  'A_926': 'Are you planning to test more people?',
#  'A_927': " Are you still confident that you'll see that kind of economic growth this year?",
#  'A_928': 'Are you telling the Americans, except for the ones who are sick, not to change any of their behaviors?',
#  'A_929': "How does that square with what you're doing right now?",
#  'A_930': 'Trust in health officials to provide good information.',
#  'A_931': ' Trust in instincts',
#  'A_932': 'Concerns regarding Americans in Brazil for Carnival',
#  'A_933': 'Procedures and practices planned for Americans trying to come back home',
#  'A_934': 'Why did you feel the need to make a change and put Vice President Mike Pence in charge of the Federal response to this virus?',
#  'A_935': 'Looking into it? Do you have a message on that?',
#  'A_936': ' Is the person currently working with China?',
#  'A_937': 'Are you going to do this more often?',
#  'A_938': 'Confidence in Secretary Azar?',
#  'A_939': "Do you agree with the intelligence community's assessment that Russia is trying to meddle in the 2020 election?",
#  'A_940': 'What is your message to Vladimir Putin about potentially interfering regardless of the candidate they support?',
#  'A_941': "What would be India's role in the region regarding the deal in Afghanistan?",
#  'A_942': "What would be Pakistan's role in the region regarding the deal in Afghanistan?",
#  'A_943': 'What is the roadmap to fight Islamic radical terrorism?',
#  'A_944': ' In the earlier discussion with Prime Minister Modi, what is the Trump doctrine on fighting Islamic fundamentalism?',
#  'A_945': 'Hi, sir, Emily Goodwin with the DailyMail.com. I was wondering, do you think justice was served in the Harvey Weinstein case?',
#  'A_946': 'Asking the President to deliver a message to women in America who are afraid to come forward',
#  'A_947': 'By your own measure, does that mean that your Government has been incompetent?',
#  'A_948': " How do you define, differentiate, and deal with the law for Indians in India and Indians' law for H-1B visa in America?",
#  'A_949': 'How do you differentiate this?',
#  'A_950': 'How large a list do you imagine this will be?',
#  'A_951': 'Is this a big problem in your mind?',
#  'A_952': 'Could you describe for us the scale of the problem as you see it?',
#  'A_953': 'What is your strategy?',
#  'A_954': 'What are you going to do?',
#  'A_955': 'What does the President mean by other sources when discussing energy security and an energy deal?',
#  'A_956': 'And is nuclear happening?',
#  'A_957': 'Justify having an Acting DNI with no intelligence experience.',
#  'A_958': 'Pledge not to accept foreign assistance in the upcoming election.',
#  'A_959': "Was he forced out because he wasn't sufficiently loyal to you?",
#  'A_960': 'How would you describe your tour of India?',
#  'A_961': 'Would you describe it as cultural diplomacy or Trump diplomacy?',
#  'A_962': 'Do you have any other word to describe your tour of India?',
#  'A_963': 'How would you describe it diplomatically?',
#  'A_964': 'Is it Trump diplomacy? Cultural diplomacy?',
#  'A_965': 'What is the administration considering to do in retaliation to the Chinese government ejecting Wall Street Journal reporters?',
#  'A_966': 'Are they considering banning or restricting the access of Chinese journalists in the United States?',
#  'A_967': 'Could there be more stringent sanctions against Venezuela?',
#  'A_968': ' Should Indian companies continue to buy from Venezuela?',
#  'A_969': 'Are the sanctions going to be against the Venezuelan entities?',
#  'A_970': 'Are the sanctions going to be against the Indian companies who are continuing to buy the Venezuelan oil?',
#  'A_971': 'Are you in a position to talk to him about those subjects?',
#  'A_972': ' Some people say that India could be to the U.S. in Asia during the 21st century what the U.K. was in Europe during the 20th century. How do you view it?',
#  'A_973': ' Are you satisfied with the Indian investment rating, especially on issues like multibrand retail and e-commerce on which companies from U.S. have a lot of interest in?',
#  'A_974': 'Hear from other world leaders and business leaders who think that she has a message that you should listen to.',
#  'A_975': ' Opinion on climate change being a hoax',
#  'A_976': ' Is abuse of power an impeachable offense?',
#  'A_977': 'Is abuse of power an impeachable offense for future Presidents?',
#  'A_978': 'The expectation of human rights in Hong Kong being part of the discussion for the phase two China trade deal.',
#  'A_979': 'What do you want?',
#  'A_980': 'Can you explain the discrepancy?',
#  'A_981': 'We now know at least 11 U.S. servicemen were airlifted from Iraq.',
#  'A_982': 'Initially, you said repeatedly to Americans that after Iran retaliated for the Soleimani strike, no Americans were injured.',
#  'A_983': 'Do you consider a potential traumatic brain injury serious?',
#  'A_984': ' Is there another avenue, other than auto tariffs?',
#  'A_985': 'Before or after the election?',
#  'A_986': 'Your election this year?',
#  'A_987': ' Request for a hint about the region or the countries.',
#  'A_988': 'Would you like to see this over quickly?',
#  'A_989': 'Would you like to see a thorough examination of the facts?',
#  'A_990': 'What did you make of the dustup between the White House Counsel Pat Cipollone and Jerrold Nadler last night?',
#  'A_991': 'Are you absolutely against John Bolton testifying?',
#  'A_992': 'How do you feel about Kenneth Starr now?',
#  'A_993': 'Will you show up at your trial any day, in any way, shape, or form?',
#  'A_994': "Why don't you go?",
#  'A_995': 'Why not commit to going?',
#  'A_996': 'Do you think Cipollone and Sekulow would want you there?',
#  'A_997': 'Do you feel that Democrats made their case?',
#  'A_998': ' How did you feel about the Republican performance?',
#  'A_999': 'Analysis of the American approach to FETÖ',
#  ...}
